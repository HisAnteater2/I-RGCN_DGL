# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q dgl-cu110
# Out:
#      |████████████████████████████████| 39.9 MB 1.5 MB/s

# %%
#!pip install dgl -f https://data.dgl.ai/wheels/repo.html

# %%
import networkx as nx
import numpy as np
import scipy.sparse
import pickle

from sklearn.model_selection import train_test_split

import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import random

import dgl
from dgl.data.knowledge_graph import load_data
from dgl.nn.pytorch import RelGraphConv
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Using backend: pytorch
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)

# %% [markdown]
# #Data Importing and Preprocessing

# %%
# %cd '/content/drive/MyDrive/'
# Out:
# /content/drive/MyDrive

# %%
def load_IMDB_data(prefix='IMDB_processed'):
    G00 = nx.read_adjlist(prefix + '/0/0-1-0.adjlist', create_using=nx.MultiDiGraph)
    G01 = nx.read_adjlist(prefix + '/0/0-2-0.adjlist', create_using=nx.MultiDiGraph)
    G10 = nx.read_adjlist(prefix + '/1/1-0-1.adjlist', create_using=nx.MultiDiGraph)
    G11 = nx.read_adjlist(prefix + '/1/1-0-2-0-1.adjlist', create_using=nx.MultiDiGraph)
    G20 = nx.read_adjlist(prefix + '/2/2-0-2.adjlist', create_using=nx.MultiDiGraph)
    G21 = nx.read_adjlist(prefix + '/2/2-0-1-0-2.adjlist', create_using=nx.MultiDiGraph)
    idx00 = np.load(prefix + '/0/0-1-0_idx.npy')
    idx01 = np.load(prefix + '/0/0-2-0_idx.npy')
    idx10 = np.load(prefix + '/1/1-0-1_idx.npy')
    idx11 = np.load(prefix + '/1/1-0-2-0-1_idx.npy')
    idx20 = np.load(prefix + '/2/2-0-2_idx.npy')
    idx21 = np.load(prefix + '/2/2-0-1-0-2_idx.npy')
    features_0 = scipy.sparse.load_npz(prefix + '/features_0.npz')
    features_1 = scipy.sparse.load_npz(prefix + '/features_1.npz')
    features_2 = scipy.sparse.load_npz(prefix + '/features_2.npz')
    adjM = scipy.sparse.load_npz(prefix + '/adjM.npz')
    type_mask = np.load(prefix + '/node_types.npy')
    labels = np.load(prefix + '/labels.npy')
    train_val_test_idx = np.load(prefix + '/train_val_test_idx.npz')
    return [[G00, G01], [G10, G11], [G20, G21]], \
           [[idx00, idx01], [idx10, idx11], [idx20, idx21]], \
           [features_0, features_1, features_2],\
           adjM, \
           type_mask,\
           labels,\
           train_val_test_idx

# %%
 nx_G_lists, edge_metapath_indices_lists, features_list, adjM, type_mask, labels, train_val_test_idx = load_IMDB_data()

# %%
features_ls = [torch.FloatTensor(features.todense()) for features in features_list]
features_ls = torch.cat((features_ls[0], features_ls[1], features_ls[2]))

# %%
adjM = adjM.toarray()

# %%
#code to transform IMDB into Edge List (dataset)
num_nodes = type_mask.size
num_edges = adjM.size
num_rels = 6
g_data=[]
for x in range(labels.size):
  for y in range(labels.size, type_mask.size):
    rel1=0
    rel2=6
    if adjM[x][y]==1:
      if type_mask[y]==1:
        if labels[x]==0:
          rel1=0
          rel2=6
        elif labels[x]==1:
          rel1=1
          rel2=7
        elif labels[x]==2:
          rel1=2
          rel2=8
      elif type_mask[y]==2:
        if labels[x]==0:
          rel1=0+3
          rel2=6+3
        elif labels[x]==1:
          rel1=1+3
          rel2=7+3
        elif labels[x]==2:
          rel1=2+3
          rel2=8+3
      g_data.append([x, rel1, y])
      #g_data.append([y, rel2, x])

# %%
np.random.seed([3,1415])

np.random.shuffle(g_data)
train_data = [x for x in g_data if x[1]!=2]
X = [x for x in g_data if x[1]==2]
irgcn_train_data = X[:100]
for x in X[:100]:
  train_data.append(x) 
test_data = X[100:]
valid_data = test_data

# %% [markdown]
# # Model

# %%
class BaseRGCN(nn.Module):
    def __init__(self, num_nodes, h_dim, out_dim, num_rels, num_bases,
                 num_hidden_layers=1, dropout=0,
                 use_self_loop=False, use_cuda=False):
        super(BaseRGCN, self).__init__()
        self.num_nodes = num_nodes
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.num_rels = num_rels
        self.num_bases = None if num_bases < 0 else num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop
        self.use_cuda = use_cuda

        # create rgcn layers
        self.build_model()

    def build_model(self):
        self.layers = nn.ModuleList()
        # i2h
        i2h = self.build_input_layer()
        if i2h is not None:
            self.layers.append(i2h)
        # h2h
        for idx in range(self.num_hidden_layers):
            h2h = self.build_hidden_layer(idx)
            self.layers.append(h2h)
        # h2o
        h2o = self.build_output_layer()
        if h2o is not None:
            self.layers.append(h2o)

    def build_input_layer(self):
        return None

    def build_hidden_layer(self, idx):
        raise NotImplementedError

    def build_output_layer(self):
        return None

    def forward(self, g, h, r, norm):
        for layer in self.layers:
            h = layer(g, h, r, norm)
        return h

# %%
class EmbeddingLayer(nn.Module):
    def __init__(self, num_nodes, h_dim):
        super(EmbeddingLayer, self).__init__()
        self.embedding = torch.nn.Embedding.from_pretrained(features_ls)
        self.linear = torch.nn.Linear(3066, h_dim)

    def forward(self, g, h, r, norm):
        return F.relu(self.linear(self.embedding(h.squeeze())))

# %%
class RGCN(BaseRGCN):
    def build_input_layer(self):
        return EmbeddingLayer(self.num_nodes, self.h_dim)

    def build_hidden_layer(self, idx):
        act = F.relu if idx < self.num_hidden_layers - 1 else None
        return RelGraphConv(self.h_dim, self.h_dim, self.num_rels, "bdd",
                self.num_bases, activation=act, self_loop=True,
                dropout=self.dropout)

# %%
class LinkPredict(nn.Module):
    def __init__(self, in_dim, h_dim, num_rels, num_bases=-1,
                 num_hidden_layers=1, dropout=0, use_cuda=False, reg_param=0):
        super(LinkPredict, self).__init__()
        self.rgcn = RGCN(in_dim, h_dim, h_dim, num_rels * 2, num_bases,
                         num_hidden_layers, dropout, use_cuda)
        self.reg_param = reg_param
        self.w_relation = nn.Parameter(torch.Tensor(num_rels, h_dim))
        nn.init.xavier_uniform_(self.w_relation,
                                gain=nn.init.calculate_gain('relu'))

    def calc_score(self, embedding, triplets):
        # DistMult
        s = embedding[triplets[:,0]]
        r = self.w_relation[triplets[:,1]]
        o = embedding[triplets[:,2]]
        score = torch.sum(s * r * o, dim=1)
        return score

    def forward(self, g, h, r, norm):
        return self.rgcn.forward(g, h, r, norm)

    def regularization_loss(self, embedding):
        return torch.mean(embedding.pow(2)) + torch.mean(self.w_relation.pow(2))

    def get_loss(self, g, embed, triplets, labels):
        # triplets is a list of data samples (positive and negative)
        # each row in the triplets is a 3-tuple of (source, relation, destination)
        score = self.calc_score(embed, triplets)
        predict_loss = F.binary_cross_entropy_with_logits(score, labels)
        reg_loss = self.regularization_loss(embed)
        return predict_loss + self.reg_param * reg_loss

# %%
class IRGCN(nn.Module):
  def __init__(self, in_dim, h_dim, num_rels, num_bases=-1,
                 num_hidden_layers=1, dropout=0, use_cuda=False, reg_param=0):
    super(IRGCN, self).__init__()
    self.embedding = LinkPredict(num_nodes,
                    parameter_n_hidden,
                    num_rels,
                    num_bases=parameter_n_bases,
                    num_hidden_layers=parameter_n_layers,
                    dropout=parameter_dropout,
                    use_cuda=use_cuda,
                    reg_param=parameter_regularization)
    self.fcc1 = torch.nn.Linear(h_dim*2, h_dim)
    self.fcc2 = torch.nn.Linear(h_dim, h_dim)
    self.w_relation = torch.zeros((num_rels, h_dim))
    self.in_dim=in_dim
    self.dropout = nn.Dropout(p=0.2)
    self.embed = 0
    self.h_dim=h_dim
    self.reg_param=reg_param
    self.num_rels=num_rels

  def calc_score(self, triplets):
    # DistMult
    s = self.embed[triplets[:,0]]
    r = self.w_relation[triplets[:,1]]
    o = self.embed[triplets[:,2]]
    score = torch.sum(s * r * o, dim=1)
    return score

  def forward(self, g, h, r, norm, triplets, labels):
    self.embed = self.embedding(g, h, r, norm)
    head = self.embed[triplets[:,0]]
    tail = self.embed[triplets[:,2]]
    x = self.fcc1(torch.cat((head, tail), 1))
    x = F.relu(x)
    x = self.dropout(x)
    x = self.fcc2(x)
    self.w_relation = torch.zeros((self.num_rels, self.h_dim))
    if use_cuda:
      self.w_relation = torch.zeros((self.num_rels, self.h_dim)).cuda()
    
    for i in range(self.num_rels):
      self.w_relation[i] = torch.mean(x[((triplets[:, 1] == i )*( labels==1)).nonzero().squeeze(1)], 0)
    # i=0
    # for op in x:
    #   if labels[i]:
    #     self.w_relation[triplets[i][1]]+=op
    #     c[triplets[i][1]]+=1
    #   i+=1
    # for i in range(self.num_rels):
    #   self.w_relation[i]/=c[i]

  def regularization_loss(self):
    return torch.mean(self.embed.pow(2)) + torch.mean(self.w_relation.pow(2))

  def get_loss(self, g, triplets, labels):
    score = self.calc_score(triplets)
    return F.binary_cross_entropy_with_logits(score, labels)+self.reg_param*self.regularization_loss()
    return torch.mean(torch.log(1+torch.exp(-labels*score)))

# %%
def node_norm_to_edge_norm(g, node_norm):
    g = g.local_var()
    # convert to edge norm
    g.ndata['norm'] = node_norm
    g.apply_edges(lambda edges : {'norm' : edges.dst['norm']})
    return g.edata['norm']

# %% [markdown]
# #Training RGCN

# %%
import sys
sys.path.insert(0,'/content/drive/My Drive/')

import utils

# %%
parameter_dropout = 0.2
parameter_gpu = 0
parameter_n_hidden = 96
parameter_n_bases = -1
parameter_n_layers = 2
parameter_n_epochs = 10000
parameter_regularization = 0.01
parameter_lr = 1e-2
parameter_graph_batch_size = 15000
parameter_graph_split_size = 0.5
parameter_negative_sample = 10
parameter_edge_sampler = "uniform"
parameter_grad_norm = 1.0
parameter_evaluate_every = 100
parameter_eval_batch_size = 500
parameter_eval_protocol = "filtered"

# %%
# load graph data
'''data = load_data('FB15k-237')
num_nodes = data.num_nodes
train_data = data.train
valid_data = data.valid
test_data = data.test
num_rels = data.num_rels'''

# check cuda
use_cuda = parameter_gpu >= 0 and torch.cuda.is_available()
if use_cuda:
    torch.cuda.set_device(parameter_gpu)

# create model
model = LinkPredict(num_nodes,
                    parameter_n_hidden,
                    num_rels,
                    num_bases=parameter_n_bases,
                    num_hidden_layers=parameter_n_layers,
                    dropout=parameter_dropout,
                    use_cuda=use_cuda,
                    reg_param=parameter_regularization)

# validation and testing triplets
train_data = np.array(train_data)
valid_data = torch.LongTensor(valid_data)
test_data = torch.LongTensor(test_data)

# build test graph
test_graph, test_rel, test_norm = utils.build_test_graph(
    num_nodes, num_rels, train_data)
test_deg = test_graph.in_degrees(
            range(test_graph.number_of_nodes())).float().view(-1,1)
test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
test_rel = torch.from_numpy(test_rel)
test_norm = node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))

if use_cuda:
    model.cuda()

# build adj list and calculate degrees for sampling
adj_list, degrees = utils.get_adj_and_degrees(num_nodes, train_data)

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=parameter_lr)

model_state_file = 'model_state.pth'
forward_time = []
backward_time = []

# training loop
print("start training...")

epoch = 0
best_mrr = 0
while True:
    model.train()
    epoch += 1

    # perform edge neighborhood sampling to generate training graph and data
    g, node_id, edge_type, node_norm, data, labels = \
        utils.generate_sampled_graph_and_labels(
            train_data, parameter_graph_batch_size, parameter_graph_split_size,
            num_rels, adj_list, degrees, parameter_negative_sample,
            parameter_edge_sampler)
    print("Done edge sampling")
    # set node/edge feature
    node_id = torch.from_numpy(node_id).view(-1, 1).long()
    edge_type = torch.from_numpy(edge_type)
    edge_norm = node_norm_to_edge_norm(g, torch.from_numpy(node_norm).view(-1, 1))
    data, labels = torch.from_numpy(data), torch.from_numpy(labels)
    deg = g.in_degrees(range(g.number_of_nodes())).float().view(-1, 1)
    if use_cuda:
        node_id, deg = node_id.cuda(), deg.cuda()
        edge_type, edge_norm = edge_type.cuda(), edge_norm.cuda()
        data, labels = data.cuda(), labels.cuda()
        g = g.to(parameter_gpu)
        test_node_id_g = test_node_id.cuda()
        test_rel_g = test_rel.cuda()
        test_norm_g = test_norm.cuda()
        test_graph_g = test_graph.to(parameter_gpu)
    
    t0 = time.time()
    embed = model(g, node_id, edge_type, edge_norm)
    loss = model.get_loss(g, embed, data, labels)
    t1 = time.time()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), parameter_grad_norm) # clip gradients
    optimizer.step()
    t2 = time.time()

    forward_time.append(t1 - t0)
    backward_time.append(t2 - t1)
    print("Epoch {:04d} | Loss {:.4f} | Best MRR {:.4f} | Forward {:.4f}s | Backward {:.4f}s".
          format(epoch, loss.item(), best_mrr, forward_time[-1], backward_time[-1]))

    optimizer.zero_grad()

    # validation
    if epoch % parameter_evaluate_every == 0:
        # perform validation on CPU because full graph is too large
        if use_cuda:
            model.cpu()
        model.eval()
        print("start eval")
        embed = model(test_graph, test_node_id, test_rel, test_norm)
        mrr = utils.calc_mrr(embed, model.w_relation, torch.LongTensor(train_data),
                              valid_data, test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size,
                              eval_p=parameter_eval_protocol)
        # save best model
        if best_mrr < mrr:
            best_mrr = mrr
            torch.save({'state_dict': model.state_dict(), 'epoch': epoch}, model_state_file)
        
        if epoch >= parameter_n_epochs:
            break
        
        if use_cuda:
            model.cuda()

print("training done")
print("Mean forward time: {:4f}s".format(np.mean(forward_time)))
print("Mean Backward time: {:4f}s".format(np.mean(backward_time)))

print("\nstart testing:")
# use best model checkpoint
checkpoint = torch.load(model_state_file)
if use_cuda:
    model.cpu() # test on CPU
model.eval()
model.load_state_dict(checkpoint['state_dict'])
print("Using best epoch: {}".format(checkpoint['epoch']))
embed = model(test_graph, test_node_id, test_rel, test_norm)
utils.calc_mrr(embed, model.w_relation, torch.LongTensor(train_data), valid_data,
                test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size, eval_p=parameter_eval_protocol)
# Out:
# Test graph:
# /content/drive/My Drive/utils.py:122: RuntimeWarning: divide by zero encountered in true_divide
#   norm = 1.0 / in_deg
# Streaming output truncated to the last 5000 lines.
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0090 | Loss 0.2196 | Best MRR 0.0000 | Forward 0.0283s | Backward 0.0044s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0091 | Loss 0.2174 | Best MRR 0.0000 | Forward 0.0287s | Backward 0.0057s
# # sampled nodes: 10865
# # sampled edges: 15000
# # nodes: 10865, # edges: 15000
# Done edge sampling
# Epoch 0092 | Loss 0.2137 | Best MRR 0.0000 | Forward 0.0287s | Backward 0.0043s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0093 | Loss 0.2138 | Best MRR 0.0000 | Forward 0.0288s | Backward 0.0069s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0094 | Loss 0.2099 | Best MRR 0.0000 | Forward 0.0287s | Backward 0.0043s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0095 | Loss 0.2094 | Best MRR 0.0000 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0096 | Loss 0.2077 | Best MRR 0.0000 | Forward 0.0283s | Backward 0.0044s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0097 | Loss 0.2062 | Best MRR 0.0000 | Forward 0.0285s | Backward 0.0041s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0098 | Loss 0.2035 | Best MRR 0.0000 | Forward 0.0284s | Backward 0.0044s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0099 | Loss 0.2008 | Best MRR 0.0000 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0100 | Loss 0.2014 | Best MRR 0.0000 | Forward 0.0285s | Backward 0.0046s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.028444
# Hits (filtered) @ 1: 0.007539
# Hits (filtered) @ 3: 0.023646
# Hits (filtered) @ 10: 0.063742
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0101 | Loss 0.1982 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0053s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0102 | Loss 0.1952 | Best MRR 0.0284 | Forward 0.0291s | Backward 0.0044s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0103 | Loss 0.1949 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0104 | Loss 0.1948 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0061s
# # sampled nodes: 10864
# # sampled edges: 15000
# # nodes: 10864, # edges: 15000
# Done edge sampling
# Epoch 0105 | Loss 0.1911 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0106 | Loss 0.1900 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0107 | Loss 0.1879 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0108 | Loss 0.1870 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0109 | Loss 0.1834 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0043s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0110 | Loss 0.1825 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0042s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0111 | Loss 0.1817 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0112 | Loss 0.1802 | Best MRR 0.0284 | Forward 0.0300s | Backward 0.0047s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0113 | Loss 0.1791 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0114 | Loss 0.1761 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0115 | Loss 0.1762 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0042s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0116 | Loss 0.1737 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0117 | Loss 0.1720 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0118 | Loss 0.1700 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0119 | Loss 0.1702 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0042s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0120 | Loss 0.1683 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0050s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0121 | Loss 0.1669 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0048s
# # sampled nodes: 10862
# # sampled edges: 15000
# # nodes: 10862, # edges: 15000
# Done edge sampling
# Epoch 0122 | Loss 0.1656 | Best MRR 0.0284 | Forward 0.0291s | Backward 0.0060s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0123 | Loss 0.1634 | Best MRR 0.0284 | Forward 0.0303s | Backward 0.0069s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0124 | Loss 0.1651 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0045s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0125 | Loss 0.1620 | Best MRR 0.0284 | Forward 0.0293s | Backward 0.0052s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0126 | Loss 0.1587 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0049s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0127 | Loss 0.1593 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0128 | Loss 0.1569 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0129 | Loss 0.1570 | Best MRR 0.0284 | Forward 0.0291s | Backward 0.0046s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0130 | Loss 0.1547 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0131 | Loss 0.1554 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0132 | Loss 0.1558 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0053s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0133 | Loss 0.1518 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0134 | Loss 0.1510 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0051s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0135 | Loss 0.1497 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0136 | Loss 0.1495 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0042s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0137 | Loss 0.1480 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0138 | Loss 0.1474 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0046s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0139 | Loss 0.1466 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0140 | Loss 0.1458 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0141 | Loss 0.1471 | Best MRR 0.0284 | Forward 0.0300s | Backward 0.0050s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0142 | Loss 0.1452 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0143 | Loss 0.1429 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0059s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0144 | Loss 0.1436 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0145 | Loss 0.1409 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0146 | Loss 0.1422 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0047s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0147 | Loss 0.1409 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0057s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0148 | Loss 0.1395 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0043s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0149 | Loss 0.1378 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0150 | Loss 0.1365 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0043s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0151 | Loss 0.1383 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0152 | Loss 0.1363 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0058s
# # sampled nodes: 10868
# # sampled edges: 15000
# # nodes: 10868, # edges: 15000
# Done edge sampling
# Epoch 0153 | Loss 0.1346 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0043s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0154 | Loss 0.1357 | Best MRR 0.0284 | Forward 0.0291s | Backward 0.0055s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0155 | Loss 0.1345 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0048s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0156 | Loss 0.1356 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0157 | Loss 0.1327 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10870
# # sampled edges: 15000
# # nodes: 10870, # edges: 15000
# Done edge sampling
# Epoch 0158 | Loss 0.1325 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0042s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0159 | Loss 0.1310 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0160 | Loss 0.1293 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0161 | Loss 0.1308 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0045s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0162 | Loss 0.1302 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0163 | Loss 0.1305 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0049s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0164 | Loss 0.1287 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0165 | Loss 0.1284 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0052s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0166 | Loss 0.1277 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0167 | Loss 0.1274 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0168 | Loss 0.1256 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0068s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0169 | Loss 0.1258 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10817
# # sampled edges: 15000
# # nodes: 10817, # edges: 15000
# Done edge sampling
# Epoch 0170 | Loss 0.1261 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0049s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0171 | Loss 0.1234 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0172 | Loss 0.1240 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10860
# # sampled edges: 15000
# # nodes: 10860, # edges: 15000
# Done edge sampling
# Epoch 0173 | Loss 0.1228 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 0174 | Loss 0.1239 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0175 | Loss 0.1249 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0176 | Loss 0.1212 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0043s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 0177 | Loss 0.1247 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0178 | Loss 0.1222 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0179 | Loss 0.1235 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0180 | Loss 0.1209 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0181 | Loss 0.1199 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0182 | Loss 0.1209 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0046s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0183 | Loss 0.1194 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0184 | Loss 0.1189 | Best MRR 0.0284 | Forward 0.0292s | Backward 0.0046s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0185 | Loss 0.1203 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0048s
# # sampled nodes: 10820
# # sampled edges: 15000
# # nodes: 10820, # edges: 15000
# Done edge sampling
# Epoch 0186 | Loss 0.1179 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0042s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0187 | Loss 0.1161 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0188 | Loss 0.1181 | Best MRR 0.0284 | Forward 0.0289s | Backward 0.0060s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0189 | Loss 0.1172 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0190 | Loss 0.1171 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0043s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0191 | Loss 0.1153 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0192 | Loss 0.1141 | Best MRR 0.0284 | Forward 0.0284s | Backward 0.0044s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0193 | Loss 0.1149 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0044s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0194 | Loss 0.1160 | Best MRR 0.0284 | Forward 0.0295s | Backward 0.0053s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0195 | Loss 0.1153 | Best MRR 0.0284 | Forward 0.0288s | Backward 0.0049s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0196 | Loss 0.1145 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0197 | Loss 0.1134 | Best MRR 0.0284 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0198 | Loss 0.1135 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0199 | Loss 0.1138 | Best MRR 0.0284 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10824
# # sampled edges: 15000
# # nodes: 10824, # edges: 15000
# Done edge sampling
# Epoch 0200 | Loss 0.1137 | Best MRR 0.0284 | Forward 0.0287s | Backward 0.0048s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.188316
# Hits (filtered) @ 1: 0.103496
# Hits (filtered) @ 3: 0.243660
# Hits (filtered) @ 10: 0.305346
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0201 | Loss 0.1140 | Best MRR 0.1883 | Forward 0.0289s | Backward 0.0053s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0202 | Loss 0.1112 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0203 | Loss 0.1109 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0042s
# # sampled nodes: 10875
# # sampled edges: 15000
# # nodes: 10875, # edges: 15000
# Done edge sampling
# Epoch 0204 | Loss 0.1118 | Best MRR 0.1883 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0205 | Loss 0.1112 | Best MRR 0.1883 | Forward 0.0299s | Backward 0.0058s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0206 | Loss 0.1100 | Best MRR 0.1883 | Forward 0.0289s | Backward 0.0121s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0207 | Loss 0.1091 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0208 | Loss 0.1102 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0050s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0209 | Loss 0.1096 | Best MRR 0.1883 | Forward 0.0291s | Backward 0.0058s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0210 | Loss 0.1094 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0211 | Loss 0.1100 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0048s
# # sampled nodes: 10860
# # sampled edges: 15000
# # nodes: 10860, # edges: 15000
# Done edge sampling
# Epoch 0212 | Loss 0.1076 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10868
# # sampled edges: 15000
# # nodes: 10868, # edges: 15000
# Done edge sampling
# Epoch 0213 | Loss 0.1093 | Best MRR 0.1883 | Forward 0.0291s | Backward 0.0055s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0214 | Loss 0.1093 | Best MRR 0.1883 | Forward 0.0284s | Backward 0.0047s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0215 | Loss 0.1086 | Best MRR 0.1883 | Forward 0.0290s | Backward 0.0047s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0216 | Loss 0.1085 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0217 | Loss 0.1064 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0218 | Loss 0.1082 | Best MRR 0.1883 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10820
# # sampled edges: 15000
# # nodes: 10820, # edges: 15000
# Done edge sampling
# Epoch 0219 | Loss 0.1074 | Best MRR 0.1883 | Forward 0.0297s | Backward 0.0063s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0220 | Loss 0.1060 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0221 | Loss 0.1073 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0222 | Loss 0.1071 | Best MRR 0.1883 | Forward 0.0295s | Backward 0.0068s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0223 | Loss 0.1047 | Best MRR 0.1883 | Forward 0.0294s | Backward 0.0068s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0224 | Loss 0.1064 | Best MRR 0.1883 | Forward 0.0297s | Backward 0.0095s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0225 | Loss 0.1064 | Best MRR 0.1883 | Forward 0.0291s | Backward 0.0057s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0226 | Loss 0.1053 | Best MRR 0.1883 | Forward 0.0308s | Backward 0.0061s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0227 | Loss 0.1047 | Best MRR 0.1883 | Forward 0.0288s | Backward 0.0058s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 0228 | Loss 0.1054 | Best MRR 0.1883 | Forward 0.0288s | Backward 0.0043s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0229 | Loss 0.1052 | Best MRR 0.1883 | Forward 0.0325s | Backward 0.0044s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0230 | Loss 0.1039 | Best MRR 0.1883 | Forward 0.0295s | Backward 0.0045s
# # sampled nodes: 10824
# # sampled edges: 15000
# # nodes: 10824, # edges: 15000
# Done edge sampling
# Epoch 0231 | Loss 0.1040 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0232 | Loss 0.1022 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0233 | Loss 0.1031 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 0234 | Loss 0.1016 | Best MRR 0.1883 | Forward 0.0298s | Backward 0.0052s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0235 | Loss 0.1018 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0042s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0236 | Loss 0.1032 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0237 | Loss 0.1015 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0238 | Loss 0.1016 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0239 | Loss 0.1023 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0042s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0240 | Loss 0.1011 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0241 | Loss 0.1015 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0242 | Loss 0.1010 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0243 | Loss 0.1009 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0244 | Loss 0.1008 | Best MRR 0.1883 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0245 | Loss 0.1023 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0053s
# # sampled nodes: 10870
# # sampled edges: 15000
# # nodes: 10870, # edges: 15000
# Done edge sampling
# Epoch 0246 | Loss 0.1000 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0049s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0247 | Loss 0.1004 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0248 | Loss 0.0990 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0249 | Loss 0.0996 | Best MRR 0.1883 | Forward 0.0298s | Backward 0.0045s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0250 | Loss 0.0991 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0048s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0251 | Loss 0.0987 | Best MRR 0.1883 | Forward 0.0291s | Backward 0.0076s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0252 | Loss 0.0996 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0253 | Loss 0.0988 | Best MRR 0.1883 | Forward 0.0289s | Backward 0.0046s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0254 | Loss 0.0973 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0255 | Loss 0.0977 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0256 | Loss 0.0970 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10873
# # sampled edges: 15000
# # nodes: 10873, # edges: 15000
# Done edge sampling
# Epoch 0257 | Loss 0.0989 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0258 | Loss 0.0973 | Best MRR 0.1883 | Forward 0.0332s | Backward 0.0068s
# # sampled nodes: 10814
# # sampled edges: 15000
# # nodes: 10814, # edges: 15000
# Done edge sampling
# Epoch 0259 | Loss 0.0990 | Best MRR 0.1883 | Forward 0.0288s | Backward 0.0048s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0260 | Loss 0.0979 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0261 | Loss 0.0946 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0262 | Loss 0.0971 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0049s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0263 | Loss 0.0956 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0264 | Loss 0.0956 | Best MRR 0.1883 | Forward 0.0296s | Backward 0.0048s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0265 | Loss 0.0966 | Best MRR 0.1883 | Forward 0.0296s | Backward 0.0044s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0266 | Loss 0.0971 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10860
# # sampled edges: 15000
# # nodes: 10860, # edges: 15000
# Done edge sampling
# Epoch 0267 | Loss 0.0958 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0268 | Loss 0.0960 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0269 | Loss 0.0956 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0270 | Loss 0.0958 | Best MRR 0.1883 | Forward 0.0284s | Backward 0.0046s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0271 | Loss 0.0958 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0272 | Loss 0.0952 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0273 | Loss 0.0957 | Best MRR 0.1883 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0274 | Loss 0.0956 | Best MRR 0.1883 | Forward 0.0294s | Backward 0.0049s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0275 | Loss 0.0950 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0276 | Loss 0.0942 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0277 | Loss 0.0951 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0278 | Loss 0.0941 | Best MRR 0.1883 | Forward 0.0288s | Backward 0.0060s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0279 | Loss 0.0949 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0280 | Loss 0.0932 | Best MRR 0.1883 | Forward 0.0290s | Backward 0.0061s
# # sampled nodes: 10811
# # sampled edges: 15000
# # nodes: 10811, # edges: 15000
# Done edge sampling
# Epoch 0281 | Loss 0.0928 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0282 | Loss 0.0941 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0283 | Loss 0.0923 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0284 | Loss 0.0931 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0285 | Loss 0.0948 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0286 | Loss 0.0922 | Best MRR 0.1883 | Forward 0.0292s | Backward 0.0061s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0287 | Loss 0.0925 | Best MRR 0.1883 | Forward 0.0284s | Backward 0.0046s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0288 | Loss 0.0939 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0050s
# # sampled nodes: 10873
# # sampled edges: 15000
# # nodes: 10873, # edges: 15000
# Done edge sampling
# Epoch 0289 | Loss 0.0926 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0290 | Loss 0.0927 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10824
# # sampled edges: 15000
# # nodes: 10824, # edges: 15000
# Done edge sampling
# Epoch 0291 | Loss 0.0922 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0292 | Loss 0.0918 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0293 | Loss 0.0903 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0294 | Loss 0.0908 | Best MRR 0.1883 | Forward 0.0300s | Backward 0.0060s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0295 | Loss 0.0912 | Best MRR 0.1883 | Forward 0.0290s | Backward 0.0059s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0296 | Loss 0.0910 | Best MRR 0.1883 | Forward 0.0285s | Backward 0.0048s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0297 | Loss 0.0909 | Best MRR 0.1883 | Forward 0.0294s | Backward 0.0066s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0298 | Loss 0.0911 | Best MRR 0.1883 | Forward 0.0288s | Backward 0.0045s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0299 | Loss 0.0900 | Best MRR 0.1883 | Forward 0.0287s | Backward 0.0044s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0300 | Loss 0.0903 | Best MRR 0.1883 | Forward 0.0286s | Backward 0.0045s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.213626
# Hits (filtered) @ 1: 0.117546
# Hits (filtered) @ 3: 0.269020
# Hits (filtered) @ 10: 0.362234
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0301 | Loss 0.0900 | Best MRR 0.2136 | Forward 0.0291s | Backward 0.0090s
# # sampled nodes: 10818
# # sampled edges: 15000
# # nodes: 10818, # edges: 15000
# Done edge sampling
# Epoch 0302 | Loss 0.0899 | Best MRR 0.2136 | Forward 0.0288s | Backward 0.0045s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0303 | Loss 0.0900 | Best MRR 0.2136 | Forward 0.0284s | Backward 0.0046s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0304 | Loss 0.0897 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0047s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0305 | Loss 0.0900 | Best MRR 0.2136 | Forward 0.0290s | Backward 0.0062s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0306 | Loss 0.0895 | Best MRR 0.2136 | Forward 0.0292s | Backward 0.0067s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0307 | Loss 0.0898 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10860
# # sampled edges: 15000
# # nodes: 10860, # edges: 15000
# Done edge sampling
# Epoch 0308 | Loss 0.0893 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10874
# # sampled edges: 15000
# # nodes: 10874, # edges: 15000
# Done edge sampling
# Epoch 0309 | Loss 0.0902 | Best MRR 0.2136 | Forward 0.0289s | Backward 0.0048s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0310 | Loss 0.0884 | Best MRR 0.2136 | Forward 0.0287s | Backward 0.0044s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0311 | Loss 0.0906 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0312 | Loss 0.0878 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0313 | Loss 0.0877 | Best MRR 0.2136 | Forward 0.0288s | Backward 0.0051s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0314 | Loss 0.0877 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0315 | Loss 0.0889 | Best MRR 0.2136 | Forward 0.0288s | Backward 0.0129s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0316 | Loss 0.0883 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0317 | Loss 0.0873 | Best MRR 0.2136 | Forward 0.0288s | Backward 0.0047s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0318 | Loss 0.0880 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0059s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0319 | Loss 0.0867 | Best MRR 0.2136 | Forward 0.0295s | Backward 0.0048s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0320 | Loss 0.0881 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0321 | Loss 0.0886 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0322 | Loss 0.0870 | Best MRR 0.2136 | Forward 0.0294s | Backward 0.0082s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0323 | Loss 0.0883 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0324 | Loss 0.0886 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0325 | Loss 0.0879 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0326 | Loss 0.0878 | Best MRR 0.2136 | Forward 0.0288s | Backward 0.0048s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0327 | Loss 0.0880 | Best MRR 0.2136 | Forward 0.0287s | Backward 0.0044s
# # sampled nodes: 10869
# # sampled edges: 15000
# # nodes: 10869, # edges: 15000
# Done edge sampling
# Epoch 0328 | Loss 0.0877 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10820
# # sampled edges: 15000
# # nodes: 10820, # edges: 15000
# Done edge sampling
# Epoch 0329 | Loss 0.0856 | Best MRR 0.2136 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0330 | Loss 0.0867 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0074s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0331 | Loss 0.0874 | Best MRR 0.2136 | Forward 0.0290s | Backward 0.0052s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0332 | Loss 0.0860 | Best MRR 0.2136 | Forward 0.0298s | Backward 0.0100s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0333 | Loss 0.0871 | Best MRR 0.2136 | Forward 0.0287s | Backward 0.0074s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0334 | Loss 0.0868 | Best MRR 0.2136 | Forward 0.0295s | Backward 0.0084s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0335 | Loss 0.0870 | Best MRR 0.2136 | Forward 0.0290s | Backward 0.0076s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0336 | Loss 0.0851 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0337 | Loss 0.0848 | Best MRR 0.2136 | Forward 0.0295s | Backward 0.0074s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0338 | Loss 0.0857 | Best MRR 0.2136 | Forward 0.0297s | Backward 0.0045s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0339 | Loss 0.0844 | Best MRR 0.2136 | Forward 0.0289s | Backward 0.0052s
# # sampled nodes: 10867
# # sampled edges: 15000
# # nodes: 10867, # edges: 15000
# Done edge sampling
# Epoch 0340 | Loss 0.0843 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0341 | Loss 0.0846 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0342 | Loss 0.0853 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0343 | Loss 0.0870 | Best MRR 0.2136 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0344 | Loss 0.0864 | Best MRR 0.2136 | Forward 0.0287s | Backward 0.0048s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 0345 | Loss 0.0853 | Best MRR 0.2136 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# ...
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0938 | Loss 0.0605 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10862
# # sampled edges: 15000
# # nodes: 10862, # edges: 15000
# Done edge sampling
# Epoch 0939 | Loss 0.0611 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0048s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0940 | Loss 0.0613 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0941 | Loss 0.0619 | Best MRR 0.2231 | Forward 0.0293s | Backward 0.0051s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0942 | Loss 0.0610 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0943 | Loss 0.0606 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0043s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0944 | Loss 0.0622 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0945 | Loss 0.0604 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0042s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0946 | Loss 0.0609 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10864
# # sampled edges: 15000
# # nodes: 10864, # edges: 15000
# Done edge sampling
# Epoch 0947 | Loss 0.0608 | Best MRR 0.2231 | Forward 0.0284s | Backward 0.0070s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 0948 | Loss 0.0603 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0949 | Loss 0.0610 | Best MRR 0.2231 | Forward 0.0293s | Backward 0.0045s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0950 | Loss 0.0618 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0042s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0951 | Loss 0.0598 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0952 | Loss 0.0613 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0953 | Loss 0.0606 | Best MRR 0.2231 | Forward 0.0284s | Backward 0.0043s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0954 | Loss 0.0606 | Best MRR 0.2231 | Forward 0.0289s | Backward 0.0051s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 0955 | Loss 0.0607 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0047s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0956 | Loss 0.0603 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0957 | Loss 0.0612 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0045s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0958 | Loss 0.0610 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0959 | Loss 0.0610 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0960 | Loss 0.0600 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0072s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0961 | Loss 0.0602 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0048s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0962 | Loss 0.0612 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0043s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0963 | Loss 0.0597 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0964 | Loss 0.0622 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0965 | Loss 0.0627 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0047s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0966 | Loss 0.0618 | Best MRR 0.2231 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10862
# # sampled edges: 15000
# # nodes: 10862, # edges: 15000
# Done edge sampling
# Epoch 0967 | Loss 0.0610 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10869
# # sampled edges: 15000
# # nodes: 10869, # edges: 15000
# Done edge sampling
# Epoch 0968 | Loss 0.0624 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0969 | Loss 0.0598 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0970 | Loss 0.0635 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0046s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0971 | Loss 0.0639 | Best MRR 0.2231 | Forward 0.0292s | Backward 0.0059s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0972 | Loss 0.0605 | Best MRR 0.2231 | Forward 0.0295s | Backward 0.0056s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0973 | Loss 0.0615 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0046s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0974 | Loss 0.0642 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0044s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0975 | Loss 0.0602 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0048s
# # sampled nodes: 10862
# # sampled edges: 15000
# # nodes: 10862, # edges: 15000
# Done edge sampling
# Epoch 0976 | Loss 0.0615 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0977 | Loss 0.0624 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 0978 | Loss 0.0605 | Best MRR 0.2231 | Forward 0.0291s | Backward 0.0047s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0979 | Loss 0.0627 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0044s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0980 | Loss 0.0620 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0981 | Loss 0.0604 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0982 | Loss 0.0621 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0983 | Loss 0.0606 | Best MRR 0.2231 | Forward 0.0284s | Backward 0.0045s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0984 | Loss 0.0619 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0985 | Loss 0.0604 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0062s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0986 | Loss 0.0594 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0987 | Loss 0.0608 | Best MRR 0.2231 | Forward 0.0284s | Backward 0.0044s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0988 | Loss 0.0620 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0989 | Loss 0.0596 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0048s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0990 | Loss 0.0589 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0047s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0991 | Loss 0.0598 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0044s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0992 | Loss 0.0590 | Best MRR 0.2231 | Forward 0.0292s | Backward 0.0046s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0993 | Loss 0.0595 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0994 | Loss 0.0603 | Best MRR 0.2231 | Forward 0.0289s | Backward 0.0041s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0995 | Loss 0.0597 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0049s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0996 | Loss 0.0600 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10860
# # sampled edges: 15000
# # nodes: 10860, # edges: 15000
# Done edge sampling
# Epoch 0997 | Loss 0.0598 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0998 | Loss 0.0586 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0046s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0999 | Loss 0.0595 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0044s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 1000 | Loss 0.0585 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0042s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.204414
# Hits (filtered) @ 1: 0.102125
# Hits (filtered) @ 3: 0.255655
# Hits (filtered) @ 10: 0.379712
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 1001 | Loss 0.0592 | Best MRR 0.2231 | Forward 0.0288s | Backward 0.0044s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 1002 | Loss 0.0591 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 1003 | Loss 0.0593 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0042s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 1004 | Loss 0.0592 | Best MRR 0.2231 | Forward 0.0289s | Backward 0.0049s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 1005 | Loss 0.0612 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0043s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 1006 | Loss 0.0594 | Best MRR 0.2231 | Forward 0.0287s | Backward 0.0045s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 1007 | Loss 0.0591 | Best MRR 0.2231 | Forward 0.0298s | Backward 0.0067s
# # sampled nodes: 10865
# # sampled edges: 15000
# # nodes: 10865, # edges: 15000
# Done edge sampling
# Epoch 1008 | Loss 0.0588 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0043s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 1009 | Loss 0.0591 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0043s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 1010 | Loss 0.0595 | Best MRR 0.2231 | Forward 0.0286s | Backward 0.0045s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 1011 | Loss 0.0586 | Best MRR 0.2231 | Forward 0.0289s | Backward 0.0046s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 1012 | Loss 0.0613 | Best MRR 0.2231 | Forward 0.0289s | Backward 0.0045s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 1013 | Loss 0.0580 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 1014 | Loss 0.0595 | Best MRR 0.2231 | Forward 0.0290s | Backward 0.0047s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 1015 | Loss 0.0589 | Best MRR 0.2231 | Forward 0.0285s | Backward 0.0043s
# # sampled nodes: 10837
# # sampled edges: 15000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-77c00df247e7> in <module>()
#      62             train_data, parameter_graph_batch_size, parameter_graph_split_size,
#      63             num_rels, adj_list, degrees, parameter_negative_sample,
# ---> 64             parameter_edge_sampler)
#      65     print("Done edge sampling")
#      66     # set node/edge feature
#
# /content/drive/My Drive/utils.py in generate_sampled_graph_and_labels(triplets, sample_size, split_size, num_rels, adj_list, degrees, negative_rate, sampler)
#     114     print("# sampled edges: {}".format(len(src) * 2))
#     115     g, rel, norm = build_graph_from_triplets(len(uniq_v), num_rels,
# --> 116                                              (src, rel, dst))
#     117     return g, uniq_v, rel, norm, samples, labels
#     118
#
# /content/drive/My Drive/utils.py in build_graph_from_triplets(num_nodes, num_rels, triplets)
#     135     src, dst = np.concatenate((src, dst)), np.concatenate((dst, src))
#     136     rel = np.concatenate((rel, rel + num_rels))
# --> 137     edges = sorted(zip(dst, src, rel))
#     138     dst, src, rel = np.array(edges).transpose()
#     139     g.add_edges(src, dst)
#
# KeyboardInterrupt:

# %% [markdown]
# #Training IRGCN

# %%
import sys
sys.path.insert(0,'/content/drive/My Drive/')

import utils

# %%
np.random.seed([3,1415])

np.random.shuffle(g_data)
train_data = [x for x in g_data if x[1]!=2]
X = [x for x in g_data if x[1]==2]
irgcn_train_data = X[:100]
for x in X[:100]:
  train_data.append(x) 
test_data = X[100:]
valid_data = test_data

# %%
parameter_dropout = 0.2
parameter_gpu = 0
parameter_n_hidden = 96
parameter_n_bases = -1
parameter_n_layers = 1
parameter_n_epochs = 10000
parameter_regularization = 0.01
parameter_lr = 1e-2
parameter_graph_batch_size = 15000
parameter_graph_split_size = 0.5
parameter_negative_sample = 10
parameter_edge_sampler = "uniform"
parameter_grad_norm = 1.0
parameter_evaluate_every = 100
parameter_eval_batch_size = 500
parameter_eval_protocol = "filtered"

# %%
train_data = np.array(train_data)
valid_data = torch.LongTensor(valid_data)
test_data = torch.LongTensor(test_data)
train_data=train_data[train_data[:, 1].argsort()]

# %%
#train_data = irgcn_train_data
# check cuda
use_cuda = parameter_gpu >= 0 and torch.cuda.is_available()
if use_cuda:
    torch.cuda.set_device(parameter_gpu)

# create model
model = IRGCN(num_nodes,
                    parameter_n_hidden,
                    num_rels,
                    num_bases=parameter_n_bases,
                    num_hidden_layers=parameter_n_layers,
                    dropout=parameter_dropout,
                    use_cuda=use_cuda,
                    reg_param=parameter_regularization)

# validation and testing triplets
train_data = np.array(train_data)
valid_data = torch.LongTensor(valid_data)
test_data = torch.LongTensor(test_data)

# build test graph
test_graph, test_rel, test_norm = utils.build_test_graph(
    num_nodes, num_rels, train_data)
test_deg = test_graph.in_degrees(
            range(test_graph.number_of_nodes())).float().view(-1,1)
test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
test_rel = torch.from_numpy(test_rel)
test_norm = node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))

if use_cuda:
    model.cuda()

# build adj list and calculate degrees for sampling
adj_list, degrees = utils.get_adj_and_degrees(num_nodes, train_data)

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=parameter_lr)

model_state_file = 'model_state_irgcn.pth'
forward_time = []
backward_time = []

# training loop
print("start training...")

epoch = 0
best_mrr = 0
while True:
    model.train()
    epoch += 1

    # perform edge neighborhood sampling to generate training graph and data
    g, node_id, edge_type, node_norm, data, labels = \
        utils.generate_sampled_graph_and_labels(
            train_data, parameter_graph_batch_size, parameter_graph_split_size,
            num_rels, adj_list, degrees, parameter_negative_sample,
            parameter_edge_sampler)
    print("Done edge sampling")
    #labels =(labels-0.5)*2
    # set node/edge feature
    node_id = torch.from_numpy(node_id).view(-1, 1).long()
    edge_type = torch.from_numpy(edge_type)
    edge_norm = node_norm_to_edge_norm(g, torch.from_numpy(node_norm).view(-1, 1))
    data, labels = torch.from_numpy(data), torch.from_numpy(labels)
    deg = g.in_degrees(range(g.number_of_nodes())).float().view(-1, 1)
    if use_cuda:
        node_id, deg = node_id.cuda(), deg.cuda()
        edge_type, edge_norm = edge_type.cuda(), edge_norm.cuda()
        data, labels = data.cuda(), labels.cuda()
        g = g.to(parameter_gpu)
        data, labels = data.cuda(), labels.cuda()

    t0 = time.time()


    model(g, node_id, edge_type, edge_norm, data, labels)

    loss = model.get_loss(g, data, labels)
    t1 = time.time()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), parameter_grad_norm) # clip gradients
    optimizer.step()
    t2 = time.time()

    forward_time.append(t1 - t0)
    backward_time.append(t2 - t1)
    print("Epoch {:04d} | Loss {:.4f} | Best MRR {:.4f} | Forward {:.4f}s | Backward {:.4f}s".
          format(epoch, loss.item(), best_mrr, forward_time[-1], backward_time[-1]))

    optimizer.zero_grad()

    # validation
    if epoch % parameter_evaluate_every == 0:
        # perform validation on CPU because full graph is too large
        if use_cuda:
            model.cpu()
        model.eval()
        print("start eval")
        mrr = utils.calc_mrr(model.embedding(test_graph, test_node_id, test_rel, test_norm), model.w_relation.cpu(), torch.LongTensor(train_data).cpu(),
                              valid_data, test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size,
                              eval_p=parameter_eval_protocol)
        # save best model
        if best_mrr < mrr:
            best_mrr = mrr
            torch.save({'state_dict': model.state_dict(), 'epoch': epoch}, model_state_file)
        
        if epoch >= parameter_n_epochs:
            break
        
        if use_cuda:
            model.cuda()

print("training done")
print("Mean forward time: {:4f}s".format(np.mean(forward_time)))
print("Mean Backward time: {:4f}s".format(np.mean(backward_time)))

print("\nstart testing:")
# use best model checkpoint
checkpoint = torch.load(model_state_file)
if use_cuda:
    model.cpu() # test on CPU
model.eval()
model.load_state_dict(checkpoint['state_dict'])
print("Using best epoch: {}".format(checkpoint['epoch']))
utils.calc_mrr(model.embedding(test_graph, test_node_id, test_rel, test_norm), model.w_relation, torch.LongTensor(train_data), valid_data,
                test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size, eval_p=parameter_eval_protocol)
# Out:
# Test graph:
# /content/drive/My Drive/utils.py:122: RuntimeWarning: divide by zero encountered in true_divide
#   norm = 1.0 / in_deg
# Streaming output truncated to the last 5000 lines.
# Done edge sampling
# Epoch 0112 | Loss 0.0861 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1852s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0113 | Loss 0.0850 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1770s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0114 | Loss 0.0838 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1833s
# # sampled nodes: 10822
# # sampled edges: 15000
# # nodes: 10822, # edges: 15000
# Done edge sampling
# Epoch 0115 | Loss 0.0845 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1832s
# # sampled nodes: 10821
# # sampled edges: 15000
# # nodes: 10821, # edges: 15000
# Done edge sampling
# Epoch 0116 | Loss 0.0820 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1851s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0117 | Loss 0.0831 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1801s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0118 | Loss 0.0809 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1769s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0119 | Loss 0.0823 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1800s
# # sampled nodes: 10817
# # sampled edges: 15000
# # nodes: 10817, # edges: 15000
# Done edge sampling
# Epoch 0120 | Loss 0.0822 | Best MRR 0.2484 | Forward 0.0428s | Backward 0.1781s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0121 | Loss 0.0804 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1808s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0122 | Loss 0.0805 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1823s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0123 | Loss 0.0794 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1834s
# # sampled nodes: 10876
# # sampled edges: 15000
# # nodes: 10876, # edges: 15000
# Done edge sampling
# Epoch 0124 | Loss 0.0792 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1819s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0125 | Loss 0.0799 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1783s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0126 | Loss 0.0802 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1842s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0127 | Loss 0.0782 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1865s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0128 | Loss 0.0789 | Best MRR 0.2484 | Forward 0.0436s | Backward 0.1815s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0129 | Loss 0.0780 | Best MRR 0.2484 | Forward 0.0433s | Backward 0.1837s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0130 | Loss 0.0779 | Best MRR 0.2484 | Forward 0.0426s | Backward 0.1875s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0131 | Loss 0.0769 | Best MRR 0.2484 | Forward 0.0448s | Backward 0.1819s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0132 | Loss 0.0767 | Best MRR 0.2484 | Forward 0.0442s | Backward 0.1836s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0133 | Loss 0.0759 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1778s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0134 | Loss 0.0748 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1778s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0135 | Loss 0.0744 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1854s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0136 | Loss 0.0742 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1834s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0137 | Loss 0.0743 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1784s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0138 | Loss 0.0732 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1857s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0139 | Loss 0.0741 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1802s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0140 | Loss 0.0733 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1805s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0141 | Loss 0.0723 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1856s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0142 | Loss 0.0713 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1796s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0143 | Loss 0.0722 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1855s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0144 | Loss 0.0695 | Best MRR 0.2484 | Forward 0.0424s | Backward 0.1814s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0145 | Loss 0.0714 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1837s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0146 | Loss 0.0728 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1805s
# # sampled nodes: 10868
# # sampled edges: 15000
# # nodes: 10868, # edges: 15000
# Done edge sampling
# Epoch 0147 | Loss 0.0705 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1840s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0148 | Loss 0.0703 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1823s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0149 | Loss 0.0696 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1834s
# # sampled nodes: 10822
# # sampled edges: 15000
# # nodes: 10822, # edges: 15000
# Done edge sampling
# Epoch 0150 | Loss 0.0692 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1813s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0151 | Loss 0.0672 | Best MRR 0.2484 | Forward 0.0427s | Backward 0.1839s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0152 | Loss 0.0683 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1806s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0153 | Loss 0.0683 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1805s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0154 | Loss 0.0689 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1834s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0155 | Loss 0.0694 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1892s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0156 | Loss 0.0681 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1862s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0157 | Loss 0.0649 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1817s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0158 | Loss 0.0668 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1858s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0159 | Loss 0.0664 | Best MRR 0.2484 | Forward 0.0426s | Backward 0.1832s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0160 | Loss 0.0686 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1884s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0161 | Loss 0.0665 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1800s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0162 | Loss 0.0662 | Best MRR 0.2484 | Forward 0.0434s | Backward 0.1813s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 0163 | Loss 0.0672 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1867s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0164 | Loss 0.0648 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1860s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0165 | Loss 0.0656 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1810s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0166 | Loss 0.0651 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1827s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0167 | Loss 0.0652 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1818s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0168 | Loss 0.0652 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1814s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0169 | Loss 0.0638 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1833s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0170 | Loss 0.0658 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1861s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0171 | Loss 0.0646 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1799s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0172 | Loss 0.0650 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1837s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0173 | Loss 0.0631 | Best MRR 0.2484 | Forward 0.0431s | Backward 0.1810s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0174 | Loss 0.0636 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1851s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0175 | Loss 0.0641 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1832s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0176 | Loss 0.0623 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1802s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0177 | Loss 0.0632 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1867s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0178 | Loss 0.0624 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1817s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0179 | Loss 0.0613 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1794s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0180 | Loss 0.0611 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1831s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0181 | Loss 0.0614 | Best MRR 0.2484 | Forward 0.0431s | Backward 0.1850s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0182 | Loss 0.0614 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1806s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0183 | Loss 0.0613 | Best MRR 0.2484 | Forward 0.0422s | Backward 0.1844s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0184 | Loss 0.0609 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1839s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0185 | Loss 0.0600 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1831s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0186 | Loss 0.0609 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1831s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0187 | Loss 0.0608 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1821s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0188 | Loss 0.0601 | Best MRR 0.2484 | Forward 0.0418s | Backward 0.1853s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0189 | Loss 0.0604 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1808s
# # sampled nodes: 10818
# # sampled edges: 15000
# # nodes: 10818, # edges: 15000
# Done edge sampling
# Epoch 0190 | Loss 0.0579 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1806s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0191 | Loss 0.0615 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1822s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0192 | Loss 0.0606 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1813s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0193 | Loss 0.0591 | Best MRR 0.2484 | Forward 0.0419s | Backward 0.1836s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0194 | Loss 0.0586 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1824s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0195 | Loss 0.0575 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1842s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0196 | Loss 0.0593 | Best MRR 0.2484 | Forward 0.0421s | Backward 0.1842s
# # sampled nodes: 10814
# # sampled edges: 15000
# # nodes: 10814, # edges: 15000
# Done edge sampling
# Epoch 0197 | Loss 0.0583 | Best MRR 0.2484 | Forward 0.0420s | Backward 0.1803s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0198 | Loss 0.0565 | Best MRR 0.2484 | Forward 0.0427s | Backward 0.1839s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0199 | Loss 0.0586 | Best MRR 0.2484 | Forward 0.0431s | Backward 0.1772s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0200 | Loss 0.0578 | Best MRR 0.2484 | Forward 0.0423s | Backward 0.1805s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.292059
# Hits (filtered) @ 1: 0.151131
# Hits (filtered) @ 3: 0.375600
# Hits (filtered) @ 10: 0.525017
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0201 | Loss 0.0572 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1776s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0202 | Loss 0.0578 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1818s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0203 | Loss 0.0580 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1792s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0204 | Loss 0.0570 | Best MRR 0.2921 | Forward 0.0427s | Backward 0.1783s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0205 | Loss 0.0570 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1837s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0206 | Loss 0.0575 | Best MRR 0.2921 | Forward 0.0422s | Backward 0.1798s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0207 | Loss 0.0561 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1786s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0208 | Loss 0.0565 | Best MRR 0.2921 | Forward 0.0422s | Backward 0.1802s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0209 | Loss 0.0569 | Best MRR 0.2921 | Forward 0.0422s | Backward 0.1837s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0210 | Loss 0.0555 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1821s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0211 | Loss 0.0554 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1828s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0212 | Loss 0.0556 | Best MRR 0.2921 | Forward 0.0428s | Backward 0.1813s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0213 | Loss 0.0546 | Best MRR 0.2921 | Forward 0.0426s | Backward 0.1788s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0214 | Loss 0.0551 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1866s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0215 | Loss 0.0560 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1778s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0216 | Loss 0.0556 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1811s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0217 | Loss 0.0545 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1818s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0218 | Loss 0.0562 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1841s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0219 | Loss 0.0550 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1809s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0220 | Loss 0.0544 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1888s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0221 | Loss 0.0549 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1814s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0222 | Loss 0.0536 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1852s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0223 | Loss 0.0537 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1810s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0224 | Loss 0.0535 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1802s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0225 | Loss 0.0542 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1849s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0226 | Loss 0.0535 | Best MRR 0.2921 | Forward 0.0424s | Backward 0.1771s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0227 | Loss 0.0542 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1826s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0228 | Loss 0.0557 | Best MRR 0.2921 | Forward 0.0456s | Backward 0.1876s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0229 | Loss 0.0525 | Best MRR 0.2921 | Forward 0.0485s | Backward 0.1821s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0230 | Loss 0.0527 | Best MRR 0.2921 | Forward 0.0441s | Backward 0.1859s
# # sampled nodes: 10821
# # sampled edges: 15000
# # nodes: 10821, # edges: 15000
# Done edge sampling
# Epoch 0231 | Loss 0.0538 | Best MRR 0.2921 | Forward 0.0430s | Backward 0.1797s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0232 | Loss 0.0538 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1843s
# # sampled nodes: 10815
# # sampled edges: 15000
# # nodes: 10815, # edges: 15000
# Done edge sampling
# Epoch 0233 | Loss 0.0545 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1819s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0234 | Loss 0.0528 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1796s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0235 | Loss 0.0549 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1865s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0236 | Loss 0.0535 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1816s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0237 | Loss 0.0532 | Best MRR 0.2921 | Forward 0.0423s | Backward 0.1790s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0238 | Loss 0.0514 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1832s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0239 | Loss 0.0523 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1850s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0240 | Loss 0.0532 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1827s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0241 | Loss 0.0519 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1838s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0242 | Loss 0.0520 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1839s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0243 | Loss 0.0525 | Best MRR 0.2921 | Forward 0.0434s | Backward 0.1824s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0244 | Loss 0.0522 | Best MRR 0.2921 | Forward 0.0422s | Backward 0.1868s
# # sampled nodes: 10811
# # sampled edges: 15000
# # nodes: 10811, # edges: 15000
# Done edge sampling
# Epoch 0245 | Loss 0.0515 | Best MRR 0.2921 | Forward 0.0433s | Backward 0.1811s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 0246 | Loss 0.0525 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1850s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0247 | Loss 0.0516 | Best MRR 0.2921 | Forward 0.0423s | Backward 0.1778s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0248 | Loss 0.0527 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1818s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0249 | Loss 0.0524 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1831s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0250 | Loss 0.0528 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1799s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0251 | Loss 0.0516 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1776s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0252 | Loss 0.0519 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1854s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0253 | Loss 0.0503 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1791s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0254 | Loss 0.0512 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1811s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0255 | Loss 0.0500 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1857s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0256 | Loss 0.0497 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1844s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0257 | Loss 0.0500 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1812s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0258 | Loss 0.0495 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1876s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0259 | Loss 0.0504 | Best MRR 0.2921 | Forward 0.0426s | Backward 0.1799s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0260 | Loss 0.0512 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1813s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0261 | Loss 0.0498 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1841s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0262 | Loss 0.0500 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1768s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0263 | Loss 0.0498 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1817s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0264 | Loss 0.0504 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1827s
# # sampled nodes: 10824
# # sampled edges: 15000
# # nodes: 10824, # edges: 15000
# Done edge sampling
# Epoch 0265 | Loss 0.0506 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1797s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0266 | Loss 0.0498 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1829s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0267 | Loss 0.0495 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1842s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0268 | Loss 0.0513 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1765s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0269 | Loss 0.0490 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1885s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0270 | Loss 0.0501 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1804s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0271 | Loss 0.0496 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1769s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0272 | Loss 0.0499 | Best MRR 0.2921 | Forward 0.0426s | Backward 0.1845s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0273 | Loss 0.0496 | Best MRR 0.2921 | Forward 0.0425s | Backward 0.1778s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0274 | Loss 0.0503 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1878s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0275 | Loss 0.0479 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1822s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0276 | Loss 0.0487 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1838s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0277 | Loss 0.0496 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1836s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0278 | Loss 0.0487 | Best MRR 0.2921 | Forward 0.0419s | Backward 0.1831s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0279 | Loss 0.0490 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1815s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0280 | Loss 0.0506 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1866s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0281 | Loss 0.0495 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1807s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0282 | Loss 0.0491 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1891s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0283 | Loss 0.0493 | Best MRR 0.2921 | Forward 0.0431s | Backward 0.1864s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0284 | Loss 0.0498 | Best MRR 0.2921 | Forward 0.0437s | Backward 0.1803s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0285 | Loss 0.0487 | Best MRR 0.2921 | Forward 0.0422s | Backward 0.1840s
# # sampled nodes: 10865
# # sampled edges: 15000
# # nodes: 10865, # edges: 15000
# Done edge sampling
# Epoch 0286 | Loss 0.0480 | Best MRR 0.2921 | Forward 0.0422s | Backward 0.1821s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0287 | Loss 0.0482 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1827s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0288 | Loss 0.0484 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1841s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0289 | Loss 0.0499 | Best MRR 0.2921 | Forward 0.0432s | Backward 0.1810s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0290 | Loss 0.0472 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1826s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0291 | Loss 0.0482 | Best MRR 0.2921 | Forward 0.0428s | Backward 0.1807s
# # sampled nodes: 10808
# # sampled edges: 15000
# # nodes: 10808, # edges: 15000
# Done edge sampling
# Epoch 0292 | Loss 0.0488 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1847s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0293 | Loss 0.0490 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1806s
# # sampled nodes: 10860
# # sampled edges: 15000
# # nodes: 10860, # edges: 15000
# Done edge sampling
# Epoch 0294 | Loss 0.0484 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1839s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0295 | Loss 0.0477 | Best MRR 0.2921 | Forward 0.0427s | Backward 0.1851s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0296 | Loss 0.0470 | Best MRR 0.2921 | Forward 0.0421s | Backward 0.1812s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0297 | Loss 0.0477 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1810s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0298 | Loss 0.0475 | Best MRR 0.2921 | Forward 0.0426s | Backward 0.1813s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0299 | Loss 0.0483 | Best MRR 0.2921 | Forward 0.0418s | Backward 0.1845s
# # sampled nodes: 10824
# # sampled edges: 15000
# # nodes: 10824, # edges: 15000
# Done edge sampling
# Epoch 0300 | Loss 0.0488 | Best MRR 0.2921 | Forward 0.0420s | Backward 0.1817s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.299711
# Hits (filtered) @ 1: 0.151131
# Hits (filtered) @ 3: 0.382454
# Hits (filtered) @ 10: 0.559287
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0301 | Loss 0.0471 | Best MRR 0.2997 | Forward 0.0436s | Backward 0.1858s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 0302 | Loss 0.0486 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1776s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0303 | Loss 0.0480 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1810s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0304 | Loss 0.0474 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1818s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0305 | Loss 0.0479 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1788s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0306 | Loss 0.0466 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1823s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0307 | Loss 0.0467 | Best MRR 0.2997 | Forward 0.0427s | Backward 0.1808s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0308 | Loss 0.0465 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1833s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0309 | Loss 0.0468 | Best MRR 0.2997 | Forward 0.0417s | Backward 0.1833s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0310 | Loss 0.0470 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1830s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0311 | Loss 0.0472 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1860s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0312 | Loss 0.0476 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1815s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0313 | Loss 0.0477 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1810s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0314 | Loss 0.0461 | Best MRR 0.2997 | Forward 0.0417s | Backward 0.1835s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0315 | Loss 0.0464 | Best MRR 0.2997 | Forward 0.0417s | Backward 0.1847s
# # sampled nodes: 10846
# # sampled edges: 15000
# # nodes: 10846, # edges: 15000
# Done edge sampling
# Epoch 0316 | Loss 0.0469 | Best MRR 0.2997 | Forward 0.0428s | Backward 0.1821s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0317 | Loss 0.0463 | Best MRR 0.2997 | Forward 0.0431s | Backward 0.1835s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 0318 | Loss 0.0458 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1810s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0319 | Loss 0.0463 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1824s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0320 | Loss 0.0466 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1818s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 0321 | Loss 0.0472 | Best MRR 0.2997 | Forward 0.0424s | Backward 0.1788s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0322 | Loss 0.0472 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1811s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0323 | Loss 0.0456 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1822s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0324 | Loss 0.0458 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1839s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0325 | Loss 0.0458 | Best MRR 0.2997 | Forward 0.0417s | Backward 0.1866s
# # sampled nodes: 10843
# # sampled edges: 15000
# # nodes: 10843, # edges: 15000
# Done edge sampling
# Epoch 0326 | Loss 0.0453 | Best MRR 0.2997 | Forward 0.0417s | Backward 0.1842s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0327 | Loss 0.0476 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1830s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0328 | Loss 0.0458 | Best MRR 0.2997 | Forward 0.0449s | Backward 0.1818s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0329 | Loss 0.0462 | Best MRR 0.2997 | Forward 0.0439s | Backward 0.1832s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0330 | Loss 0.0452 | Best MRR 0.2997 | Forward 0.0438s | Backward 0.1865s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0331 | Loss 0.0460 | Best MRR 0.2997 | Forward 0.0439s | Backward 0.2375s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0332 | Loss 0.0458 | Best MRR 0.2997 | Forward 0.0425s | Backward 0.1798s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0333 | Loss 0.0444 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1854s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0334 | Loss 0.0461 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1826s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0335 | Loss 0.0461 | Best MRR 0.2997 | Forward 0.0428s | Backward 0.1770s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0336 | Loss 0.0457 | Best MRR 0.2997 | Forward 0.0418s | Backward 0.1891s
# # sampled nodes: 10850
# # sampled edges: 15000
# # nodes: 10850, # edges: 15000
# Done edge sampling
# Epoch 0337 | Loss 0.0445 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1831s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 0338 | Loss 0.0453 | Best MRR 0.2997 | Forward 0.0423s | Backward 0.1794s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# Epoch 0339 | Loss 0.0454 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1806s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0340 | Loss 0.0456 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1841s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0341 | Loss 0.0463 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1821s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0342 | Loss 0.0453 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1874s
# # sampled nodes: 10856
# # sampled edges: 15000
# # nodes: 10856, # edges: 15000
# Done edge sampling
# Epoch 0343 | Loss 0.0450 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1815s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0344 | Loss 0.0457 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1835s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0345 | Loss 0.0455 | Best MRR 0.2997 | Forward 0.0464s | Backward 0.1873s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0346 | Loss 0.0441 | Best MRR 0.2997 | Forward 0.0433s | Backward 0.1847s
# # sampled nodes: 10822
# # sampled edges: 15000
# # nodes: 10822, # edges: 15000
# Done edge sampling
# Epoch 0347 | Loss 0.0441 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1803s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0348 | Loss 0.0442 | Best MRR 0.2997 | Forward 0.0438s | Backward 0.1868s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0349 | Loss 0.0439 | Best MRR 0.2997 | Forward 0.0425s | Backward 0.1809s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0350 | Loss 0.0454 | Best MRR 0.2997 | Forward 0.0430s | Backward 0.1817s
# # sampled nodes: 10819
# # sampled edges: 15000
# # nodes: 10819, # edges: 15000
# Done edge sampling
# Epoch 0351 | Loss 0.0465 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1796s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0352 | Loss 0.0446 | Best MRR 0.2997 | Forward 0.0427s | Backward 0.1769s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0353 | Loss 0.0454 | Best MRR 0.2997 | Forward 0.0418s | Backward 0.1803s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 0354 | Loss 0.0442 | Best MRR 0.2997 | Forward 0.0417s | Backward 0.1835s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0355 | Loss 0.0439 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1801s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0356 | Loss 0.0461 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1851s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0357 | Loss 0.0461 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1805s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0358 | Loss 0.0446 | Best MRR 0.2997 | Forward 0.0421s | Backward 0.1797s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 0359 | Loss 0.0448 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1831s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0360 | Loss 0.0436 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1842s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0361 | Loss 0.0446 | Best MRR 0.2997 | Forward 0.0418s | Backward 0.1804s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0362 | Loss 0.0444 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1781s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 0363 | Loss 0.0437 | Best MRR 0.2997 | Forward 0.0434s | Backward 0.1786s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0364 | Loss 0.0456 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1801s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0365 | Loss 0.0446 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1806s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0366 | Loss 0.0434 | Best MRR 0.2997 | Forward 0.0424s | Backward 0.1833s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 0367 | Loss 0.0447 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1845s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0368 | Loss 0.0451 | Best MRR 0.2997 | Forward 0.0418s | Backward 0.1815s
# # sampled nodes: 10853
# # sampled edges: 15000
# # nodes: 10853, # edges: 15000
# Done edge sampling
# Epoch 0369 | Loss 0.0444 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1870s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 0370 | Loss 0.0442 | Best MRR 0.2997 | Forward 0.0419s | Backward 0.1832s
# # sampled nodes: 10820
# # sampled edges: 15000
# # nodes: 10820, # edges: 15000
# Done edge sampling
# Epoch 0371 | Loss 0.0428 | Best MRR 0.2997 | Forward 0.0422s | Backward 0.1797s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 0372 | Loss 0.0438 | Best MRR 0.2997 | Forward 0.0420s | Backward 0.1809s
# # sampled nodes: 10835
# # sampled edges: 15000
# # nodes: 10835, # edges: 15000
# Done edge sampling
# ...
# Done edge sampling
# Epoch 0967 | Loss 0.0352 | Best MRR 0.3160 | Forward 0.0417s | Backward 0.1848s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 0968 | Loss 0.0342 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1851s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 0969 | Loss 0.0325 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1851s
# # sampled nodes: 10839
# # sampled edges: 15000
# # nodes: 10839, # edges: 15000
# Done edge sampling
# Epoch 0970 | Loss 0.0359 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1830s
# # sampled nodes: 10869
# # sampled edges: 15000
# # nodes: 10869, # edges: 15000
# Done edge sampling
# Epoch 0971 | Loss 0.0337 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1842s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0972 | Loss 0.0344 | Best MRR 0.3160 | Forward 0.0427s | Backward 0.1845s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0973 | Loss 0.0338 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1882s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0974 | Loss 0.0331 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1813s
# # sampled nodes: 10827
# # sampled edges: 15000
# # nodes: 10827, # edges: 15000
# Done edge sampling
# Epoch 0975 | Loss 0.0335 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1817s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0976 | Loss 0.0325 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1803s
# # sampled nodes: 10830
# # sampled edges: 15000
# # nodes: 10830, # edges: 15000
# Done edge sampling
# Epoch 0977 | Loss 0.0333 | Best MRR 0.3160 | Forward 0.0426s | Backward 0.1806s
# # sampled nodes: 10834
# # sampled edges: 15000
# # nodes: 10834, # edges: 15000
# Done edge sampling
# Epoch 0978 | Loss 0.0336 | Best MRR 0.3160 | Forward 0.0421s | Backward 0.1794s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 0979 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0424s | Backward 0.1842s
# # sampled nodes: 10845
# # sampled edges: 15000
# # nodes: 10845, # edges: 15000
# Done edge sampling
# Epoch 0980 | Loss 0.0338 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1835s
# # sampled nodes: 10842
# # sampled edges: 15000
# # nodes: 10842, # edges: 15000
# Done edge sampling
# Epoch 0981 | Loss 0.0331 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1858s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0982 | Loss 0.0343 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1849s
# # sampled nodes: 10859
# # sampled edges: 15000
# # nodes: 10859, # edges: 15000
# Done edge sampling
# Epoch 0983 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1837s
# # sampled nodes: 10824
# # sampled edges: 15000
# # nodes: 10824, # edges: 15000
# Done edge sampling
# Epoch 0984 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1876s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0985 | Loss 0.0342 | Best MRR 0.3160 | Forward 0.0423s | Backward 0.1831s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0986 | Loss 0.0321 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1826s
# # sampled nodes: 10820
# # sampled edges: 15000
# # nodes: 10820, # edges: 15000
# Done edge sampling
# Epoch 0987 | Loss 0.0341 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1832s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0988 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1844s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 0989 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0425s | Backward 0.1834s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 0990 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1827s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 0991 | Loss 0.0331 | Best MRR 0.3160 | Forward 0.0421s | Backward 0.1832s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 0992 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1810s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 0993 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1813s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0994 | Loss 0.0338 | Best MRR 0.3160 | Forward 0.0422s | Backward 0.1793s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 0995 | Loss 0.0324 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1813s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 0996 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1867s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 0997 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1810s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 0998 | Loss 0.0327 | Best MRR 0.3160 | Forward 0.0422s | Backward 0.1841s
# # sampled nodes: 10826
# # sampled edges: 15000
# # nodes: 10826, # edges: 15000
# Done edge sampling
# Epoch 0999 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1817s
# # sampled nodes: 10852
# # sampled edges: 15000
# # nodes: 10852, # edges: 15000
# Done edge sampling
# Epoch 1000 | Loss 0.0323 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1874s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.309509
# Hits (filtered) @ 1: 0.158328
# Hits (filtered) @ 3: 0.384167
# Hits (filtered) @ 10: 0.588759
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 1001 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1820s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 1002 | Loss 0.0318 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1854s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 1003 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1800s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 1004 | Loss 0.0328 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1874s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 1005 | Loss 0.0326 | Best MRR 0.3160 | Forward 0.0422s | Backward 0.1781s
# # sampled nodes: 10844
# # sampled edges: 15000
# # nodes: 10844, # edges: 15000
# Done edge sampling
# Epoch 1006 | Loss 0.0327 | Best MRR 0.3160 | Forward 0.0434s | Backward 0.1823s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 1007 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1820s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 1008 | Loss 0.0334 | Best MRR 0.3160 | Forward 0.0422s | Backward 0.1807s
# # sampled nodes: 10832
# # sampled edges: 15000
# # nodes: 10832, # edges: 15000
# Done edge sampling
# Epoch 1009 | Loss 0.0321 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1821s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 1010 | Loss 0.0333 | Best MRR 0.3160 | Forward 0.0428s | Backward 0.1808s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 1011 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0423s | Backward 0.1828s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 1012 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0421s | Backward 0.1862s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 1013 | Loss 0.0332 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1863s
# # sampled nodes: 10838
# # sampled edges: 15000
# # nodes: 10838, # edges: 15000
# Done edge sampling
# Epoch 1014 | Loss 0.0316 | Best MRR 0.3160 | Forward 0.0429s | Backward 0.1828s
# # sampled nodes: 10820
# # sampled edges: 15000
# # nodes: 10820, # edges: 15000
# Done edge sampling
# Epoch 1015 | Loss 0.0328 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1861s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 1016 | Loss 0.0325 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1916s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 1017 | Loss 0.0326 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1838s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 1018 | Loss 0.0326 | Best MRR 0.3160 | Forward 0.0429s | Backward 0.1807s
# # sampled nodes: 10854
# # sampled edges: 15000
# # nodes: 10854, # edges: 15000
# Done edge sampling
# Epoch 1019 | Loss 0.0321 | Best MRR 0.3160 | Forward 0.0429s | Backward 0.1782s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 1020 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0421s | Backward 0.1876s
# # sampled nodes: 10851
# # sampled edges: 15000
# # nodes: 10851, # edges: 15000
# Done edge sampling
# Epoch 1021 | Loss 0.0334 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1859s
# # sampled nodes: 10849
# # sampled edges: 15000
# # nodes: 10849, # edges: 15000
# Done edge sampling
# Epoch 1022 | Loss 0.0311 | Best MRR 0.3160 | Forward 0.0427s | Backward 0.1828s
# # sampled nodes: 10823
# # sampled edges: 15000
# # nodes: 10823, # edges: 15000
# Done edge sampling
# Epoch 1023 | Loss 0.0320 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1845s
# # sampled nodes: 10828
# # sampled edges: 15000
# # nodes: 10828, # edges: 15000
# Done edge sampling
# Epoch 1024 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1789s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 1025 | Loss 0.0338 | Best MRR 0.3160 | Forward 0.0425s | Backward 0.1801s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 1026 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1838s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 1027 | Loss 0.0322 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1815s
# # sampled nodes: 10837
# # sampled edges: 15000
# # nodes: 10837, # edges: 15000
# Done edge sampling
# Epoch 1028 | Loss 0.0325 | Best MRR 0.3160 | Forward 0.0421s | Backward 0.1860s
# # sampled nodes: 10836
# # sampled edges: 15000
# # nodes: 10836, # edges: 15000
# Done edge sampling
# Epoch 1029 | Loss 0.0328 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1857s
# # sampled nodes: 10831
# # sampled edges: 15000
# # nodes: 10831, # edges: 15000
# Done edge sampling
# Epoch 1030 | Loss 0.0326 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1856s
# # sampled nodes: 10841
# # sampled edges: 15000
# # nodes: 10841, # edges: 15000
# Done edge sampling
# Epoch 1031 | Loss 0.0329 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1786s
# # sampled nodes: 10833
# # sampled edges: 15000
# # nodes: 10833, # edges: 15000
# Done edge sampling
# Epoch 1032 | Loss 0.0331 | Best MRR 0.3160 | Forward 0.0424s | Backward 0.1811s
# # sampled nodes: 10847
# # sampled edges: 15000
# # nodes: 10847, # edges: 15000
# Done edge sampling
# Epoch 1033 | Loss 0.0330 | Best MRR 0.3160 | Forward 0.0426s | Backward 0.1815s
# # sampled nodes: 10822
# # sampled edges: 15000
# # nodes: 10822, # edges: 15000
# Done edge sampling
# Epoch 1034 | Loss 0.0323 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1783s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 1035 | Loss 0.0326 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1854s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 1036 | Loss 0.0324 | Best MRR 0.3160 | Forward 0.0427s | Backward 0.1807s
# # sampled nodes: 10869
# # sampled edges: 15000
# # nodes: 10869, # edges: 15000
# Done edge sampling
# Epoch 1037 | Loss 0.0324 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1810s
# # sampled nodes: 10861
# # sampled edges: 15000
# # nodes: 10861, # edges: 15000
# Done edge sampling
# Epoch 1038 | Loss 0.0323 | Best MRR 0.3160 | Forward 0.0421s | Backward 0.1834s
# # sampled nodes: 10840
# # sampled edges: 15000
# # nodes: 10840, # edges: 15000
# Done edge sampling
# Epoch 1039 | Loss 0.0321 | Best MRR 0.3160 | Forward 0.0444s | Backward 0.1820s
# # sampled nodes: 10858
# # sampled edges: 15000
# # nodes: 10858, # edges: 15000
# Done edge sampling
# Epoch 1040 | Loss 0.0327 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1824s
# # sampled nodes: 10848
# # sampled edges: 15000
# # nodes: 10848, # edges: 15000
# Done edge sampling
# Epoch 1041 | Loss 0.0323 | Best MRR 0.3160 | Forward 0.0422s | Backward 0.1855s
# # sampled nodes: 10857
# # sampled edges: 15000
# # nodes: 10857, # edges: 15000
# Done edge sampling
# Epoch 1042 | Loss 0.0319 | Best MRR 0.3160 | Forward 0.0418s | Backward 0.1818s
# # sampled nodes: 10855
# # sampled edges: 15000
# # nodes: 10855, # edges: 15000
# Done edge sampling
# Epoch 1043 | Loss 0.0336 | Best MRR 0.3160 | Forward 0.0419s | Backward 0.1799s
# # sampled nodes: 10825
# # sampled edges: 15000
# # nodes: 10825, # edges: 15000
# Done edge sampling
# Epoch 1044 | Loss 0.0317 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1847s
# # sampled nodes: 10829
# # sampled edges: 15000
# # nodes: 10829, # edges: 15000
# Done edge sampling
# Epoch 1045 | Loss 0.0335 | Best MRR 0.3160 | Forward 0.0420s | Backward 0.1840s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-efa716ccbd0a> in <module>()
#      55             train_data, parameter_graph_batch_size, parameter_graph_split_size,
#      56             num_rels, adj_list, degrees, parameter_negative_sample,
# ---> 57             parameter_edge_sampler)
#      58     print("Done edge sampling")
#      59     #labels =(labels-0.5)*2
#
# /content/drive/My Drive/utils.py in generate_sampled_graph_and_labels(triplets, sample_size, split_size, num_rels, adj_list, degrees, negative_rate, sampler)
#      99     # negative sampling
#     100     samples, labels = negative_sampling(relabeled_edges, len(uniq_v),
# --> 101                                         negative_rate)
#     102
#     103     # further split graph, only half of the edges will be used as graph
#
# /content/drive/My Drive/utils.py in negative_sampling(pos_samples, num_entity, negative_rate)
#     154     labels[: size_of_batch] = 1
#     155     values = np.random.randint(num_entity, size=num_to_generate)
# --> 156     choices = np.random.uniform(size=num_to_generate)
#     157     subj = choices > 0.5
#     158     obj = choices <= 0.5
#
# KeyboardInterrupt:

# %%
model_state_file = 'model_state_irgcn.pth'
checkpoint = torch.load(model_state_file)
if use_cuda:
    model.cpu() # test on CPU
model.eval()
model.load_state_dict(checkpoint['state_dict'])
print("Using best epoch: {}".format(checkpoint['epoch']))
utils.calc_mrr(model.embedding(test_graph, test_node_id, test_rel, test_norm), model.w_relation.cpu(), torch.LongTensor(train_data), valid_data,
                test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size, eval_p=parameter_eval_protocol)
# Out:
# Using best epoch: 800
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.315866
# Hits (filtered) @ 1: 0.164154
# Hits (filtered) @ 3: 0.392049
# Hits (filtered) @ 10: 0.590816
# 0.3158656358718872

# %% [markdown]
# #Playground

# %%
# load graph data
'''data = load_data('FB15k-237')
num_nodes = data.num_nodes
train_data = data.train
valid_data = data.valid
test_data = data.test
num_rels = data.num_rels'''

# check cuda
use_cuda = parameter_gpu >= 0 and torch.cuda.is_available()
if use_cuda:
    torch.cuda.set_device(parameter_gpu)

# create model
model = LinkPredict(num_nodes,
                    parameter_n_hidden,
                    num_rels,
                    num_bases=parameter_n_bases,
                    num_hidden_layers=parameter_n_layers,
                    dropout=parameter_dropout,
                    use_cuda=use_cuda,
                    reg_param=parameter_regularization)

# validation and testing triplets
train_data = np.array(train_data)
valid_data = torch.LongTensor(valid_data)
test_data = torch.LongTensor(test_data)

# build test graph
test_graph, test_rel, test_norm = utils.build_test_graph(
    num_nodes, num_rels, train_data)
test_deg = test_graph.in_degrees(
            range(test_graph.number_of_nodes())).float().view(-1,1)
test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
test_rel = torch.from_numpy(test_rel)
test_norm = node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))

if use_cuda:
    model.cuda()

# build adj list and calculate degrees for sampling
adj_list, degrees = utils.get_adj_and_degrees(num_nodes, train_data)

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=parameter_lr)

model_state_file = 'model_state.pth'
forward_time = []
backward_time = []

# training loop
print("start training...")

epoch = 0
best_mrr = 0
while True:
    model.train()
    epoch += 1

    # perform edge neighborhood sampling to generate training graph and data
    g, node_id, edge_type, node_norm, data, labels = \
        utils.generate_sampled_graph_and_labels(
            train_data, parameter_graph_batch_size, parameter_graph_split_size,
            num_rels, adj_list, degrees, parameter_negative_sample,
            parameter_edge_sampler)
    print("Done edge sampling")
    # set node/edge feature
    node_id = torch.from_numpy(node_id).view(-1, 1).long()
    edge_type = torch.from_numpy(edge_type)
    edge_norm = node_norm_to_edge_norm(g, torch.from_numpy(node_norm).view(-1, 1))
    data, labels = torch.from_numpy(data), torch.from_numpy(labels)
    deg = g.in_degrees(range(g.number_of_nodes())).float().view(-1, 1)
    if use_cuda:
        node_id, deg = node_id.cuda(), deg.cuda()
        edge_type, edge_norm = edge_type.cuda(), edge_norm.cuda()
        data, labels = data.cuda(), labels.cuda()
        g = g.to(parameter_gpu)
        test_node_id_g = test_node_id.cuda()
        test_rel_g = test_rel.cuda()
        test_norm_g = test_norm.cuda()
        test_graph_g = test_graph.to(parameter_gpu)
    
    t0 = time.time()
    embed = model(g, node_id, edge_type, edge_norm)
    loss = model.get_loss(g, embed, data, labels)
    t1 = time.time()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), parameter_grad_norm) # clip gradients
    optimizer.step()
    t2 = time.time()

    forward_time.append(t1 - t0)
    backward_time.append(t2 - t1)
    print("Epoch {:04d} | Loss {:.4f} | Best MRR {:.4f} | Forward {:.4f}s | Backward {:.4f}s".
          format(epoch, loss.item(), best_mrr, forward_time[-1], backward_time[-1]))

    optimizer.zero_grad()

    # validation
    if epoch % parameter_evaluate_every == 0:
        # perform validation on CPU because full graph is too large
        if use_cuda:
            model.cpu()
        model.eval()
        print("start eval")
        embed = model(test_graph, test_node_id, test_rel, test_norm)
        mrr = utils.calc_mrr(embed, model.w_relation, torch.LongTensor(train_data),
                              valid_data, test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size,
                              eval_p=parameter_eval_protocol)
        # save best model
        if best_mrr < mrr:
            best_mrr = mrr
            torch.save({'state_dict': model.state_dict(), 'epoch': epoch}, model_state_file)
        
        if epoch >= parameter_n_epochs:
            break
        
        if use_cuda:
            model.cuda()

print("training done")
print("Mean forward time: {:4f}s".format(np.mean(forward_time)))
print("Mean Backward time: {:4f}s".format(np.mean(backward_time)))

print("\nstart testing:")
# use best model checkpoint
checkpoint = torch.load(model_state_file)
if use_cuda:
    model.cpu() # test on CPU
model.eval()
model.load_state_dict(checkpoint['state_dict'])
print("Using best epoch: {}".format(checkpoint['epoch']))
embed = model(test_graph, test_node_id, test_rel, test_norm)
utils.calc_mrr(embed, model.w_relation, torch.LongTensor(train_data), valid_data,
                test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size, eval_p=parameter_eval_protocol)
# Out:
# Test graph:
# # nodes: 11616, # edges: 65506
# start training...
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# /content/drive/My Drive/utils.py:122: RuntimeWarning: divide by zero encountered in true_divide
#   norm = 1.0 / in_deg
# Epoch 0001 | Loss 0.6935 | Best MRR 0.0000 | Forward 0.0348s | Backward 0.0054s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0002 | Loss 0.6651 | Best MRR 0.0000 | Forward 0.0316s | Backward 0.0049s
# # sampled nodes: 9982
# # sampled edges: 15000
# # nodes: 9982, # edges: 15000
# Done edge sampling
# Epoch 0003 | Loss 0.5258 | Best MRR 0.0000 | Forward 0.0303s | Backward 0.0051s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0004 | Loss 0.6140 | Best MRR 0.0000 | Forward 0.0263s | Backward 0.0054s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0005 | Loss 0.4345 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0048s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0006 | Loss 0.4031 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0052s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0007 | Loss 0.4015 | Best MRR 0.0000 | Forward 0.0248s | Backward 0.0051s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0008 | Loss 0.3689 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0051s
# # sampled nodes: 10018
# # sampled edges: 15000
# # nodes: 10018, # edges: 15000
# Done edge sampling
# Epoch 0009 | Loss 0.3731 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0055s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 0010 | Loss 0.3735 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0054s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0011 | Loss 0.3471 | Best MRR 0.0000 | Forward 0.0265s | Backward 0.0056s
# # sampled nodes: 9961
# # sampled edges: 15000
# # nodes: 9961, # edges: 15000
# Done edge sampling
# Epoch 0012 | Loss 0.3497 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0053s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0013 | Loss 0.3540 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 10031
# # sampled edges: 15000
# # nodes: 10031, # edges: 15000
# Done edge sampling
# Epoch 0014 | Loss 0.3395 | Best MRR 0.0000 | Forward 0.0246s | Backward 0.0062s
# # sampled nodes: 9984
# # sampled edges: 15000
# # nodes: 9984, # edges: 15000
# Done edge sampling
# Epoch 0015 | Loss 0.3335 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0058s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 0016 | Loss 0.3387 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 9943
# # sampled edges: 15000
# # nodes: 9943, # edges: 15000
# Done edge sampling
# Epoch 0017 | Loss 0.3329 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0018 | Loss 0.3239 | Best MRR 0.0000 | Forward 0.0238s | Backward 0.0050s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0019 | Loss 0.3277 | Best MRR 0.0000 | Forward 0.0276s | Backward 0.0068s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0020 | Loss 0.3276 | Best MRR 0.0000 | Forward 0.0258s | Backward 0.0074s
# # sampled nodes: 9949
# # sampled edges: 15000
# # nodes: 9949, # edges: 15000
# Done edge sampling
# Epoch 0021 | Loss 0.3217 | Best MRR 0.0000 | Forward 0.0251s | Backward 0.0050s
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 0022 | Loss 0.3200 | Best MRR 0.0000 | Forward 0.0245s | Backward 0.0053s
# # sampled nodes: 9969
# # sampled edges: 15000
# # nodes: 9969, # edges: 15000
# Done edge sampling
# Epoch 0023 | Loss 0.3222 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0831s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 0024 | Loss 0.3190 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0050s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0025 | Loss 0.3160 | Best MRR 0.0000 | Forward 0.0238s | Backward 0.0050s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 0026 | Loss 0.3178 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0050s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0027 | Loss 0.3176 | Best MRR 0.0000 | Forward 0.0245s | Backward 0.0052s
# # sampled nodes: 9985
# # sampled edges: 15000
# # nodes: 9985, # edges: 15000
# Done edge sampling
# Epoch 0028 | Loss 0.3147 | Best MRR 0.0000 | Forward 0.0246s | Backward 0.0052s
# # sampled nodes: 9955
# # sampled edges: 15000
# # nodes: 9955, # edges: 15000
# Done edge sampling
# Epoch 0029 | Loss 0.3141 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0048s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0030 | Loss 0.3144 | Best MRR 0.0000 | Forward 0.0265s | Backward 0.0052s
# # sampled nodes: 9957
# # sampled edges: 15000
# # nodes: 9957, # edges: 15000
# Done edge sampling
# Epoch 0031 | Loss 0.3139 | Best MRR 0.0000 | Forward 0.0244s | Backward 0.0047s
# # sampled nodes: 10048
# # sampled edges: 15000
# # nodes: 10048, # edges: 15000
# Done edge sampling
# Epoch 0032 | Loss 0.3116 | Best MRR 0.0000 | Forward 0.0242s | Backward 0.0049s
# # sampled nodes: 9934
# # sampled edges: 15000
# # nodes: 9934, # edges: 15000
# Done edge sampling
# Epoch 0033 | Loss 0.3123 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0048s
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 0034 | Loss 0.3124 | Best MRR 0.0000 | Forward 0.0238s | Backward 0.0052s
# # sampled nodes: 10071
# # sampled edges: 15000
# # nodes: 10071, # edges: 15000
# Done edge sampling
# Epoch 0035 | Loss 0.3107 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0046s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0036 | Loss 0.3100 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0058s
# # sampled nodes: 9951
# # sampled edges: 15000
# # nodes: 9951, # edges: 15000
# Done edge sampling
# Epoch 0037 | Loss 0.3104 | Best MRR 0.0000 | Forward 0.0237s | Backward 0.0047s
# # sampled nodes: 10044
# # sampled edges: 15000
# # nodes: 10044, # edges: 15000
# Done edge sampling
# Epoch 0038 | Loss 0.3095 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0048s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0039 | Loss 0.3088 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0048s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0040 | Loss 0.3087 | Best MRR 0.0000 | Forward 0.0267s | Backward 0.0051s
# # sampled nodes: 10039
# # sampled edges: 15000
# # nodes: 10039, # edges: 15000
# Done edge sampling
# Epoch 0041 | Loss 0.3081 | Best MRR 0.0000 | Forward 0.0280s | Backward 0.0051s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0042 | Loss 0.3073 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0052s
# # sampled nodes: 10005
# # sampled edges: 15000
# # nodes: 10005, # edges: 15000
# Done edge sampling
# Epoch 0043 | Loss 0.3066 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 10030
# # sampled edges: 15000
# # nodes: 10030, # edges: 15000
# Done edge sampling
# Epoch 0044 | Loss 0.3065 | Best MRR 0.0000 | Forward 0.0246s | Backward 0.0053s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0045 | Loss 0.3057 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0060s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0046 | Loss 0.3040 | Best MRR 0.0000 | Forward 0.0242s | Backward 0.0047s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 0047 | Loss 0.3039 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0048 | Loss 0.3027 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0048s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0049 | Loss 0.3019 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0050 | Loss 0.3013 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 0051 | Loss 0.3002 | Best MRR 0.0000 | Forward 0.0244s | Backward 0.0067s
# # sampled nodes: 10026
# # sampled edges: 15000
# # nodes: 10026, # edges: 15000
# Done edge sampling
# Epoch 0052 | Loss 0.2988 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0052s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0053 | Loss 0.2975 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0055s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0054 | Loss 0.2964 | Best MRR 0.0000 | Forward 0.0277s | Backward 0.0049s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0055 | Loss 0.2950 | Best MRR 0.0000 | Forward 0.0260s | Backward 0.0051s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0056 | Loss 0.2940 | Best MRR 0.0000 | Forward 0.0245s | Backward 0.0840s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0057 | Loss 0.2932 | Best MRR 0.0000 | Forward 0.0244s | Backward 0.0054s
# # sampled nodes: 9953
# # sampled edges: 15000
# # nodes: 9953, # edges: 15000
# Done edge sampling
# Epoch 0058 | Loss 0.2916 | Best MRR 0.0000 | Forward 0.0237s | Backward 0.0051s
# # sampled nodes: 10045
# # sampled edges: 15000
# # nodes: 10045, # edges: 15000
# Done edge sampling
# Epoch 0059 | Loss 0.2903 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0060 | Loss 0.2889 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0050s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0061 | Loss 0.2875 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0056s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0062 | Loss 0.2858 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0063 | Loss 0.2847 | Best MRR 0.0000 | Forward 0.0242s | Backward 0.0053s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0064 | Loss 0.2829 | Best MRR 0.0000 | Forward 0.0246s | Backward 0.0049s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0065 | Loss 0.2815 | Best MRR 0.0000 | Forward 0.0289s | Backward 0.0070s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0066 | Loss 0.2808 | Best MRR 0.0000 | Forward 0.0266s | Backward 0.0056s
# # sampled nodes: 10054
# # sampled edges: 15000
# # nodes: 10054, # edges: 15000
# Done edge sampling
# Epoch 0067 | Loss 0.2780 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0122s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0068 | Loss 0.2773 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.1014s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0069 | Loss 0.2753 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0052s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0070 | Loss 0.2743 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0051s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0071 | Loss 0.2733 | Best MRR 0.0000 | Forward 0.0255s | Backward 0.0062s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 0072 | Loss 0.2715 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0054s
# # sampled nodes: 9961
# # sampled edges: 15000
# # nodes: 9961, # edges: 15000
# Done edge sampling
# Epoch 0073 | Loss 0.2701 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0056s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0074 | Loss 0.2693 | Best MRR 0.0000 | Forward 0.0265s | Backward 0.0065s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0075 | Loss 0.2675 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0076 | Loss 0.2662 | Best MRR 0.0000 | Forward 0.0256s | Backward 0.0061s
# # sampled nodes: 9990
# # sampled edges: 15000
# # nodes: 9990, # edges: 15000
# Done edge sampling
# Epoch 0077 | Loss 0.2654 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0056s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0078 | Loss 0.2657 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0057s
# # sampled nodes: 9982
# # sampled edges: 15000
# # nodes: 9982, # edges: 15000
# Done edge sampling
# Epoch 0079 | Loss 0.2629 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0050s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0080 | Loss 0.2613 | Best MRR 0.0000 | Forward 0.0247s | Backward 0.0053s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0081 | Loss 0.2616 | Best MRR 0.0000 | Forward 0.0256s | Backward 0.0066s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0082 | Loss 0.2604 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0050s
# # sampled nodes: 9935
# # sampled edges: 15000
# # nodes: 9935, # edges: 15000
# Done edge sampling
# Epoch 0083 | Loss 0.2584 | Best MRR 0.0000 | Forward 0.0238s | Backward 0.0053s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0084 | Loss 0.2569 | Best MRR 0.0000 | Forward 0.0245s | Backward 0.0050s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 0085 | Loss 0.2567 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0086 | Loss 0.2564 | Best MRR 0.0000 | Forward 0.0242s | Backward 0.0050s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0087 | Loss 0.2543 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0067s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0088 | Loss 0.2523 | Best MRR 0.0000 | Forward 0.0280s | Backward 0.0078s
# # sampled nodes: 10051
# # sampled edges: 15000
# # nodes: 10051, # edges: 15000
# Done edge sampling
# Epoch 0089 | Loss 0.2516 | Best MRR 0.0000 | Forward 0.0244s | Backward 0.0050s
# # sampled nodes: 9935
# # sampled edges: 15000
# # nodes: 9935, # edges: 15000
# Done edge sampling
# Epoch 0090 | Loss 0.2501 | Best MRR 0.0000 | Forward 0.0241s | Backward 0.0049s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0091 | Loss 0.2497 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 10016
# # sampled edges: 15000
# # nodes: 10016, # edges: 15000
# Done edge sampling
# Epoch 0092 | Loss 0.2476 | Best MRR 0.0000 | Forward 0.0244s | Backward 0.0063s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0093 | Loss 0.2467 | Best MRR 0.0000 | Forward 0.0240s | Backward 0.0049s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0094 | Loss 0.2454 | Best MRR 0.0000 | Forward 0.0242s | Backward 0.0047s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 0095 | Loss 0.2452 | Best MRR 0.0000 | Forward 0.0236s | Backward 0.0048s
# # sampled nodes: 9984
# # sampled edges: 15000
# # nodes: 9984, # edges: 15000
# Done edge sampling
# Epoch 0096 | Loss 0.2422 | Best MRR 0.0000 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0097 | Loss 0.2426 | Best MRR 0.0000 | Forward 0.0248s | Backward 0.0048s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0098 | Loss 0.2401 | Best MRR 0.0000 | Forward 0.0245s | Backward 0.0049s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0099 | Loss 0.2389 | Best MRR 0.0000 | Forward 0.0307s | Backward 0.0049s
# # sampled nodes: 10032
# # sampled edges: 15000
# # nodes: 10032, # edges: 15000
# Done edge sampling
# Epoch 0100 | Loss 0.2364 | Best MRR 0.0000 | Forward 0.0243s | Backward 0.0047s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.009607
# Hits (filtered) @ 1: 0.002399
# Hits (filtered) @ 3: 0.005141
# Hits (filtered) @ 10: 0.015079
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0101 | Loss 0.2365 | Best MRR 0.0096 | Forward 0.0354s | Backward 0.0055s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0102 | Loss 0.2332 | Best MRR 0.0096 | Forward 0.0323s | Backward 0.0066s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0103 | Loss 0.2339 | Best MRR 0.0096 | Forward 0.0290s | Backward 0.0051s
# # sampled nodes: 9984
# # sampled edges: 15000
# # nodes: 9984, # edges: 15000
# Done edge sampling
# Epoch 0104 | Loss 0.2324 | Best MRR 0.0096 | Forward 0.0263s | Backward 0.0046s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0105 | Loss 0.2308 | Best MRR 0.0096 | Forward 0.0259s | Backward 0.0050s
# # sampled nodes: 9946
# # sampled edges: 15000
# # nodes: 9946, # edges: 15000
# Done edge sampling
# Epoch 0106 | Loss 0.2291 | Best MRR 0.0096 | Forward 0.0247s | Backward 0.0049s
# # sampled nodes: 10012
# # sampled edges: 15000
# # nodes: 10012, # edges: 15000
# Done edge sampling
# Epoch 0107 | Loss 0.2279 | Best MRR 0.0096 | Forward 0.0245s | Backward 0.0049s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0108 | Loss 0.2268 | Best MRR 0.0096 | Forward 0.0241s | Backward 0.0054s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 0109 | Loss 0.2254 | Best MRR 0.0096 | Forward 0.0243s | Backward 0.0057s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0110 | Loss 0.2231 | Best MRR 0.0096 | Forward 0.0243s | Backward 0.0046s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 0111 | Loss 0.2206 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0046s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0112 | Loss 0.2199 | Best MRR 0.0096 | Forward 0.0303s | Backward 0.0073s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0113 | Loss 0.2180 | Best MRR 0.0096 | Forward 0.0254s | Backward 0.0047s
# # sampled nodes: 10033
# # sampled edges: 15000
# # nodes: 10033, # edges: 15000
# Done edge sampling
# Epoch 0114 | Loss 0.2162 | Best MRR 0.0096 | Forward 0.0242s | Backward 0.1008s
# # sampled nodes: 10052
# # sampled edges: 15000
# # nodes: 10052, # edges: 15000
# Done edge sampling
# Epoch 0115 | Loss 0.2150 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0116 | Loss 0.2134 | Best MRR 0.0096 | Forward 0.0257s | Backward 0.0054s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0117 | Loss 0.2100 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0051s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0118 | Loss 0.2093 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0119 | Loss 0.2079 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0055s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0120 | Loss 0.2055 | Best MRR 0.0096 | Forward 0.0259s | Backward 0.0050s
# # sampled nodes: 9927
# # sampled edges: 15000
# # nodes: 9927, # edges: 15000
# Done edge sampling
# Epoch 0121 | Loss 0.2034 | Best MRR 0.0096 | Forward 0.0247s | Backward 0.0054s
# # sampled nodes: 10029
# # sampled edges: 15000
# # nodes: 10029, # edges: 15000
# Done edge sampling
# Epoch 0122 | Loss 0.2019 | Best MRR 0.0096 | Forward 0.0244s | Backward 0.0052s
# # sampled nodes: 9961
# # sampled edges: 15000
# # nodes: 9961, # edges: 15000
# Done edge sampling
# Epoch 0123 | Loss 0.2017 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0124 | Loss 0.2008 | Best MRR 0.0096 | Forward 0.0295s | Backward 0.0100s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0125 | Loss 0.1982 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0126 | Loss 0.1971 | Best MRR 0.0096 | Forward 0.0237s | Backward 0.0053s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0127 | Loss 0.1956 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0049s
# # sampled nodes: 9956
# # sampled edges: 15000
# # nodes: 9956, # edges: 15000
# Done edge sampling
# Epoch 0128 | Loss 0.1949 | Best MRR 0.0096 | Forward 0.0254s | Backward 0.0053s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0129 | Loss 0.1921 | Best MRR 0.0096 | Forward 0.0251s | Backward 0.0061s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0130 | Loss 0.1899 | Best MRR 0.0096 | Forward 0.0308s | Backward 0.0049s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0131 | Loss 0.1915 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0046s
# # sampled nodes: 10026
# # sampled edges: 15000
# # nodes: 10026, # edges: 15000
# Done edge sampling
# Epoch 0132 | Loss 0.1883 | Best MRR 0.0096 | Forward 0.0257s | Backward 0.0050s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0133 | Loss 0.1882 | Best MRR 0.0096 | Forward 0.0236s | Backward 0.0046s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0134 | Loss 0.1877 | Best MRR 0.0096 | Forward 0.0250s | Backward 0.0084s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0135 | Loss 0.1853 | Best MRR 0.0096 | Forward 0.0241s | Backward 0.0052s
# # sampled nodes: 9950
# # sampled edges: 15000
# # nodes: 9950, # edges: 15000
# Done edge sampling
# Epoch 0136 | Loss 0.1847 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0053s
# # sampled nodes: 9951
# # sampled edges: 15000
# # nodes: 9951, # edges: 15000
# Done edge sampling
# Epoch 0137 | Loss 0.1831 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0050s
# # sampled nodes: 10026
# # sampled edges: 15000
# # nodes: 10026, # edges: 15000
# Done edge sampling
# Epoch 0138 | Loss 0.1813 | Best MRR 0.0096 | Forward 0.0250s | Backward 0.0049s
# # sampled nodes: 10054
# # sampled edges: 15000
# # nodes: 10054, # edges: 15000
# Done edge sampling
# Epoch 0139 | Loss 0.1808 | Best MRR 0.0096 | Forward 0.0246s | Backward 0.0682s
# # sampled nodes: 9893
# # sampled edges: 15000
# # nodes: 9893, # edges: 15000
# Done edge sampling
# Epoch 0140 | Loss 0.1794 | Best MRR 0.0096 | Forward 0.0252s | Backward 0.0095s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0141 | Loss 0.1794 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0142 | Loss 0.1778 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0046s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0143 | Loss 0.1769 | Best MRR 0.0096 | Forward 0.0254s | Backward 0.0050s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0144 | Loss 0.1762 | Best MRR 0.0096 | Forward 0.0237s | Backward 0.0046s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0145 | Loss 0.1749 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0054s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0146 | Loss 0.1742 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 10069
# # sampled edges: 15000
# # nodes: 10069, # edges: 15000
# Done edge sampling
# Epoch 0147 | Loss 0.1742 | Best MRR 0.0096 | Forward 0.0267s | Backward 0.0048s
# # sampled nodes: 9953
# # sampled edges: 15000
# # nodes: 9953, # edges: 15000
# Done edge sampling
# Epoch 0148 | Loss 0.1726 | Best MRR 0.0096 | Forward 0.0249s | Backward 0.0052s
# # sampled nodes: 9924
# # sampled edges: 15000
# # nodes: 9924, # edges: 15000
# Done edge sampling
# Epoch 0149 | Loss 0.1715 | Best MRR 0.0096 | Forward 0.0275s | Backward 0.1015s
# # sampled nodes: 10031
# # sampled edges: 15000
# # nodes: 10031, # edges: 15000
# Done edge sampling
# Epoch 0150 | Loss 0.1728 | Best MRR 0.0096 | Forward 0.0263s | Backward 0.0129s
# # sampled nodes: 9985
# # sampled edges: 15000
# # nodes: 9985, # edges: 15000
# Done edge sampling
# Epoch 0151 | Loss 0.1713 | Best MRR 0.0096 | Forward 0.0267s | Backward 0.0113s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0152 | Loss 0.1691 | Best MRR 0.0096 | Forward 0.0257s | Backward 0.0095s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0153 | Loss 0.1685 | Best MRR 0.0096 | Forward 0.0256s | Backward 0.0079s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0154 | Loss 0.1680 | Best MRR 0.0096 | Forward 0.0264s | Backward 0.0076s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0155 | Loss 0.1656 | Best MRR 0.0096 | Forward 0.0246s | Backward 0.0063s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0156 | Loss 0.1674 | Best MRR 0.0096 | Forward 0.0253s | Backward 0.0098s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0157 | Loss 0.1651 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0158 | Loss 0.1647 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0159 | Loss 0.1637 | Best MRR 0.0096 | Forward 0.0261s | Backward 0.0050s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0160 | Loss 0.1640 | Best MRR 0.0096 | Forward 0.0241s | Backward 0.0051s
# # sampled nodes: 9975
# # sampled edges: 15000
# # nodes: 9975, # edges: 15000
# Done edge sampling
# Epoch 0161 | Loss 0.1639 | Best MRR 0.0096 | Forward 0.0265s | Backward 0.0084s
# # sampled nodes: 9970
# # sampled edges: 15000
# # nodes: 9970, # edges: 15000
# Done edge sampling
# Epoch 0162 | Loss 0.1614 | Best MRR 0.0096 | Forward 0.0243s | Backward 0.0049s
# # sampled nodes: 10051
# # sampled edges: 15000
# # nodes: 10051, # edges: 15000
# Done edge sampling
# Epoch 0163 | Loss 0.1631 | Best MRR 0.0096 | Forward 0.0248s | Backward 0.0050s
# # sampled nodes: 9954
# # sampled edges: 15000
# # nodes: 9954, # edges: 15000
# Done edge sampling
# Epoch 0164 | Loss 0.1612 | Best MRR 0.0096 | Forward 0.0252s | Backward 0.0067s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 0165 | Loss 0.1600 | Best MRR 0.0096 | Forward 0.0263s | Backward 0.0050s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0166 | Loss 0.1613 | Best MRR 0.0096 | Forward 0.0237s | Backward 0.0048s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0167 | Loss 0.1587 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0047s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0168 | Loss 0.1589 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0049s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0169 | Loss 0.1576 | Best MRR 0.0096 | Forward 0.0261s | Backward 0.0062s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0170 | Loss 0.1580 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0049s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0171 | Loss 0.1568 | Best MRR 0.0096 | Forward 0.0250s | Backward 0.0050s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0172 | Loss 0.1566 | Best MRR 0.0096 | Forward 0.0247s | Backward 0.0049s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0173 | Loss 0.1533 | Best MRR 0.0096 | Forward 0.0286s | Backward 0.1011s
# # sampled nodes: 9943
# # sampled edges: 15000
# # nodes: 9943, # edges: 15000
# Done edge sampling
# Epoch 0174 | Loss 0.1530 | Best MRR 0.0096 | Forward 0.0237s | Backward 0.0051s
# # sampled nodes: 10038
# # sampled edges: 15000
# # nodes: 10038, # edges: 15000
# Done edge sampling
# Epoch 0175 | Loss 0.1549 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 9932
# # sampled edges: 15000
# # nodes: 9932, # edges: 15000
# Done edge sampling
# Epoch 0176 | Loss 0.1534 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# Epoch 0177 | Loss 0.1539 | Best MRR 0.0096 | Forward 0.0243s | Backward 0.0052s
# # sampled nodes: 9953
# # sampled edges: 15000
# # nodes: 9953, # edges: 15000
# Done edge sampling
# Epoch 0178 | Loss 0.1535 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0049s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0179 | Loss 0.1540 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0050s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0180 | Loss 0.1516 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0050s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0181 | Loss 0.1509 | Best MRR 0.0096 | Forward 0.0276s | Backward 0.0048s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0182 | Loss 0.1502 | Best MRR 0.0096 | Forward 0.0307s | Backward 0.0050s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0183 | Loss 0.1503 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0048s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0184 | Loss 0.1496 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0185 | Loss 0.1512 | Best MRR 0.0096 | Forward 0.0269s | Backward 0.0053s
# # sampled nodes: 10046
# # sampled edges: 15000
# # nodes: 10046, # edges: 15000
# Done edge sampling
# Epoch 0186 | Loss 0.1495 | Best MRR 0.0096 | Forward 0.0238s | Backward 0.0050s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 0187 | Loss 0.1483 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 9953
# # sampled edges: 15000
# # nodes: 9953, # edges: 15000
# Done edge sampling
# Epoch 0188 | Loss 0.1474 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 9947
# # sampled edges: 15000
# # nodes: 9947, # edges: 15000
# Done edge sampling
# Epoch 0189 | Loss 0.1468 | Best MRR 0.0096 | Forward 0.0271s | Backward 0.0049s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0190 | Loss 0.1478 | Best MRR 0.0096 | Forward 0.0243s | Backward 0.0049s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 0191 | Loss 0.1471 | Best MRR 0.0096 | Forward 0.0237s | Backward 0.0828s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0192 | Loss 0.1466 | Best MRR 0.0096 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 10030
# # sampled edges: 15000
# # nodes: 10030, # edges: 15000
# Done edge sampling
# Epoch 0193 | Loss 0.1441 | Best MRR 0.0096 | Forward 0.0260s | Backward 0.0059s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0194 | Loss 0.1469 | Best MRR 0.0096 | Forward 0.0241s | Backward 0.0063s
# # sampled nodes: 10035
# # sampled edges: 15000
# # nodes: 10035, # edges: 15000
# Done edge sampling
# Epoch 0195 | Loss 0.1451 | Best MRR 0.0096 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0196 | Loss 0.1440 | Best MRR 0.0096 | Forward 0.0241s | Backward 0.0052s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0197 | Loss 0.1414 | Best MRR 0.0096 | Forward 0.0251s | Backward 0.0089s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0198 | Loss 0.1451 | Best MRR 0.0096 | Forward 0.0245s | Backward 0.0076s
# # sampled nodes: 9914
# # sampled edges: 15000
# # nodes: 9914, # edges: 15000
# Done edge sampling
# Epoch 0199 | Loss 0.1421 | Best MRR 0.0096 | Forward 0.0242s | Backward 0.0053s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0200 | Loss 0.1423 | Best MRR 0.0096 | Forward 0.0306s | Backward 0.0049s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.117865
# Hits (filtered) @ 1: 0.060315
# Hits (filtered) @ 3: 0.122344
# Hits (filtered) @ 10: 0.229267
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 0201 | Loss 0.1437 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0052s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0202 | Loss 0.1412 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0053s
# # sampled nodes: 9948
# # sampled edges: 15000
# # nodes: 9948, # edges: 15000
# Done edge sampling
# Epoch 0203 | Loss 0.1414 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0053s
# # sampled nodes: 10058
# # sampled edges: 15000
# # nodes: 10058, # edges: 15000
# Done edge sampling
# Epoch 0204 | Loss 0.1399 | Best MRR 0.1179 | Forward 0.0244s | Backward 0.0058s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 0205 | Loss 0.1402 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.0048s
# # sampled nodes: 10044
# # sampled edges: 15000
# # nodes: 10044, # edges: 15000
# Done edge sampling
# Epoch 0206 | Loss 0.1400 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0047s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0207 | Loss 0.1397 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.0072s
# # sampled nodes: 9976
# # sampled edges: 15000
# # nodes: 9976, # edges: 15000
# Done edge sampling
# Epoch 0208 | Loss 0.1381 | Best MRR 0.1179 | Forward 0.0257s | Backward 0.0050s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0209 | Loss 0.1380 | Best MRR 0.1179 | Forward 0.0242s | Backward 0.0053s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0210 | Loss 0.1388 | Best MRR 0.1179 | Forward 0.0248s | Backward 0.0049s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 0211 | Loss 0.1391 | Best MRR 0.1179 | Forward 0.0251s | Backward 0.0072s
# # sampled nodes: 10061
# # sampled edges: 15000
# # nodes: 10061, # edges: 15000
# Done edge sampling
# Epoch 0212 | Loss 0.1370 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0049s
# # sampled nodes: 10043
# # sampled edges: 15000
# # nodes: 10043, # edges: 15000
# Done edge sampling
# Epoch 0213 | Loss 0.1371 | Best MRR 0.1179 | Forward 0.0257s | Backward 0.0049s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0214 | Loss 0.1371 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0215 | Loss 0.1354 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0216 | Loss 0.1355 | Best MRR 0.1179 | Forward 0.0244s | Backward 0.0051s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0217 | Loss 0.1363 | Best MRR 0.1179 | Forward 0.0248s | Backward 0.0049s
# # sampled nodes: 9929
# # sampled edges: 15000
# # nodes: 9929, # edges: 15000
# Done edge sampling
# Epoch 0218 | Loss 0.1362 | Best MRR 0.1179 | Forward 0.0292s | Backward 0.0067s
# # sampled nodes: 9920
# # sampled edges: 15000
# # nodes: 9920, # edges: 15000
# Done edge sampling
# Epoch 0219 | Loss 0.1368 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.1052s
# # sampled nodes: 9949
# # sampled edges: 15000
# # nodes: 9949, # edges: 15000
# Done edge sampling
# Epoch 0220 | Loss 0.1334 | Best MRR 0.1179 | Forward 0.0242s | Backward 0.0063s
# # sampled nodes: 9984
# # sampled edges: 15000
# # nodes: 9984, # edges: 15000
# Done edge sampling
# Epoch 0221 | Loss 0.1350 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0048s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0222 | Loss 0.1352 | Best MRR 0.1179 | Forward 0.0243s | Backward 0.0052s
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# Epoch 0223 | Loss 0.1345 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0057s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0224 | Loss 0.1348 | Best MRR 0.1179 | Forward 0.0237s | Backward 0.0048s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0225 | Loss 0.1336 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.0048s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0226 | Loss 0.1332 | Best MRR 0.1179 | Forward 0.0244s | Backward 0.0051s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0227 | Loss 0.1321 | Best MRR 0.1179 | Forward 0.0248s | Backward 0.0047s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0228 | Loss 0.1341 | Best MRR 0.1179 | Forward 0.0305s | Backward 0.0045s
# # sampled nodes: 9970
# # sampled edges: 15000
# # nodes: 9970, # edges: 15000
# Done edge sampling
# Epoch 0229 | Loss 0.1322 | Best MRR 0.1179 | Forward 0.0288s | Backward 0.0073s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0230 | Loss 0.1315 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 9942
# # sampled edges: 15000
# # nodes: 9942, # edges: 15000
# Done edge sampling
# Epoch 0231 | Loss 0.1323 | Best MRR 0.1179 | Forward 0.0235s | Backward 0.0050s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0232 | Loss 0.1320 | Best MRR 0.1179 | Forward 0.0237s | Backward 0.0049s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0233 | Loss 0.1302 | Best MRR 0.1179 | Forward 0.0243s | Backward 0.0050s
# # sampled nodes: 9990
# # sampled edges: 15000
# # nodes: 9990, # edges: 15000
# Done edge sampling
# Epoch 0234 | Loss 0.1305 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.0046s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0235 | Loss 0.1307 | Best MRR 0.1179 | Forward 0.0245s | Backward 0.0048s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0236 | Loss 0.1298 | Best MRR 0.1179 | Forward 0.0244s | Backward 0.0046s
# # sampled nodes: 9945
# # sampled edges: 15000
# # nodes: 9945, # edges: 15000
# Done edge sampling
# Epoch 0237 | Loss 0.1313 | Best MRR 0.1179 | Forward 0.0258s | Backward 0.0051s
# # sampled nodes: 9982
# # sampled edges: 15000
# # nodes: 9982, # edges: 15000
# Done edge sampling
# Epoch 0238 | Loss 0.1307 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0057s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0239 | Loss 0.1298 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0050s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0240 | Loss 0.1281 | Best MRR 0.1179 | Forward 0.0258s | Backward 0.0066s
# # sampled nodes: 9985
# # sampled edges: 15000
# # nodes: 9985, # edges: 15000
# Done edge sampling
# Epoch 0241 | Loss 0.1279 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0242 | Loss 0.1282 | Best MRR 0.1179 | Forward 0.0237s | Backward 0.0048s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0243 | Loss 0.1287 | Best MRR 0.1179 | Forward 0.0243s | Backward 0.0049s
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 0244 | Loss 0.1266 | Best MRR 0.1179 | Forward 0.0273s | Backward 0.0062s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0245 | Loss 0.1271 | Best MRR 0.1179 | Forward 0.0245s | Backward 0.0722s
# # sampled nodes: 9985
# # sampled edges: 15000
# # nodes: 9985, # edges: 15000
# Done edge sampling
# Epoch 0246 | Loss 0.1295 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0049s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0247 | Loss 0.1267 | Best MRR 0.1179 | Forward 0.0239s | Backward 0.0058s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0248 | Loss 0.1271 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0249 | Loss 0.1262 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0052s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0250 | Loss 0.1258 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0055s
# # sampled nodes: 9973
# # sampled edges: 15000
# # nodes: 9973, # edges: 15000
# Done edge sampling
# Epoch 0251 | Loss 0.1265 | Best MRR 0.1179 | Forward 0.0248s | Backward 0.0095s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0252 | Loss 0.1263 | Best MRR 0.1179 | Forward 0.0259s | Backward 0.0106s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0253 | Loss 0.1264 | Best MRR 0.1179 | Forward 0.0273s | Backward 0.0122s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0254 | Loss 0.1251 | Best MRR 0.1179 | Forward 0.0244s | Backward 0.0106s
# # sampled nodes: 10066
# # sampled edges: 15000
# # nodes: 10066, # edges: 15000
# Done edge sampling
# Epoch 0255 | Loss 0.1249 | Best MRR 0.1179 | Forward 0.0262s | Backward 0.0086s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0256 | Loss 0.1245 | Best MRR 0.1179 | Forward 0.0246s | Backward 0.0098s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0257 | Loss 0.1242 | Best MRR 0.1179 | Forward 0.0272s | Backward 0.0065s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0258 | Loss 0.1242 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0259 | Loss 0.1248 | Best MRR 0.1179 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0260 | Loss 0.1243 | Best MRR 0.1179 | Forward 0.0256s | Backward 0.0046s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0261 | Loss 0.1224 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0262 | Loss 0.1228 | Best MRR 0.1179 | Forward 0.0242s | Backward 0.0052s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0263 | Loss 0.1235 | Best MRR 0.1179 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 10065
# ...
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0713 | Loss 0.0890 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0052s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0714 | Loss 0.0880 | Best MRR 0.3054 | Forward 0.0247s | Backward 0.0048s
# # sampled nodes: 9961
# # sampled edges: 15000
# # nodes: 9961, # edges: 15000
# Done edge sampling
# Epoch 0715 | Loss 0.0900 | Best MRR 0.3054 | Forward 0.0248s | Backward 0.0051s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0716 | Loss 0.0880 | Best MRR 0.3054 | Forward 0.0240s | Backward 0.0065s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0717 | Loss 0.0881 | Best MRR 0.3054 | Forward 0.0255s | Backward 0.0051s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0718 | Loss 0.0884 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0049s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0719 | Loss 0.0884 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0053s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 0720 | Loss 0.0881 | Best MRR 0.3054 | Forward 0.0237s | Backward 0.0051s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0721 | Loss 0.0895 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0061s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 0722 | Loss 0.0886 | Best MRR 0.3054 | Forward 0.0240s | Backward 0.0048s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0723 | Loss 0.0903 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0051s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0724 | Loss 0.0897 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0047s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0725 | Loss 0.0885 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0059s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0726 | Loss 0.0895 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0049s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0727 | Loss 0.0891 | Best MRR 0.3054 | Forward 0.0243s | Backward 0.0051s
# # sampled nodes: 9984
# # sampled edges: 15000
# # nodes: 9984, # edges: 15000
# Done edge sampling
# Epoch 0728 | Loss 0.0891 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0051s
# # sampled nodes: 9946
# # sampled edges: 15000
# # nodes: 9946, # edges: 15000
# Done edge sampling
# Epoch 0729 | Loss 0.0893 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0052s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0730 | Loss 0.0887 | Best MRR 0.3054 | Forward 0.0237s | Backward 0.0048s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0731 | Loss 0.0900 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0732 | Loss 0.0882 | Best MRR 0.3054 | Forward 0.0255s | Backward 0.0052s
# # sampled nodes: 10005
# # sampled edges: 15000
# # nodes: 10005, # edges: 15000
# Done edge sampling
# Epoch 0733 | Loss 0.0891 | Best MRR 0.3054 | Forward 0.0243s | Backward 0.0060s
# # sampled nodes: 9964
# # sampled edges: 15000
# # nodes: 9964, # edges: 15000
# Done edge sampling
# Epoch 0734 | Loss 0.0889 | Best MRR 0.3054 | Forward 0.0247s | Backward 0.0053s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0735 | Loss 0.0882 | Best MRR 0.3054 | Forward 0.0244s | Backward 0.0050s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 0736 | Loss 0.0881 | Best MRR 0.3054 | Forward 0.0300s | Backward 0.0054s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0737 | Loss 0.0896 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0051s
# # sampled nodes: 10038
# # sampled edges: 15000
# # nodes: 10038, # edges: 15000
# Done edge sampling
# Epoch 0738 | Loss 0.0879 | Best MRR 0.3054 | Forward 0.0240s | Backward 0.0050s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 0739 | Loss 0.0894 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0053s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0740 | Loss 0.0891 | Best MRR 0.3054 | Forward 0.0267s | Backward 0.0051s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0741 | Loss 0.0895 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0052s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0742 | Loss 0.0889 | Best MRR 0.3054 | Forward 0.0252s | Backward 0.0076s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0743 | Loss 0.0895 | Best MRR 0.3054 | Forward 0.0248s | Backward 0.0056s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 0744 | Loss 0.0883 | Best MRR 0.3054 | Forward 0.0245s | Backward 0.0051s
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 0745 | Loss 0.0868 | Best MRR 0.3054 | Forward 0.0236s | Backward 0.0047s
# # sampled nodes: 10010
# # sampled edges: 15000
# # nodes: 10010, # edges: 15000
# Done edge sampling
# Epoch 0746 | Loss 0.0890 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0747 | Loss 0.0874 | Best MRR 0.3054 | Forward 0.0236s | Backward 0.0044s
# # sampled nodes: 9994
# # sampled edges: 15000
# # nodes: 9994, # edges: 15000
# Done edge sampling
# Epoch 0748 | Loss 0.0878 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0050s
# # sampled nodes: 9982
# # sampled edges: 15000
# # nodes: 9982, # edges: 15000
# Done edge sampling
# Epoch 0749 | Loss 0.0864 | Best MRR 0.3054 | Forward 0.0348s | Backward 0.0105s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0750 | Loss 0.0867 | Best MRR 0.3054 | Forward 0.0331s | Backward 0.0100s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 0751 | Loss 0.0880 | Best MRR 0.3054 | Forward 0.0266s | Backward 0.0067s
# # sampled nodes: 10031
# # sampled edges: 15000
# # nodes: 10031, # edges: 15000
# Done edge sampling
# Epoch 0752 | Loss 0.0893 | Best MRR 0.3054 | Forward 0.0263s | Backward 0.0111s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0753 | Loss 0.0874 | Best MRR 0.3054 | Forward 0.0251s | Backward 0.0064s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0754 | Loss 0.0875 | Best MRR 0.3054 | Forward 0.0246s | Backward 0.0092s
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 0755 | Loss 0.0884 | Best MRR 0.3054 | Forward 0.0250s | Backward 0.0059s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0756 | Loss 0.0882 | Best MRR 0.3054 | Forward 0.0248s | Backward 0.0111s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0757 | Loss 0.0881 | Best MRR 0.3054 | Forward 0.0247s | Backward 0.0051s
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# Epoch 0758 | Loss 0.0886 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0053s
# # sampled nodes: 9958
# # sampled edges: 15000
# # nodes: 9958, # edges: 15000
# Done edge sampling
# Epoch 0759 | Loss 0.0871 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0760 | Loss 0.0874 | Best MRR 0.3054 | Forward 0.0245s | Backward 0.0057s
# # sampled nodes: 10065
# # sampled edges: 15000
# # nodes: 10065, # edges: 15000
# Done edge sampling
# Epoch 0761 | Loss 0.0883 | Best MRR 0.3054 | Forward 0.0261s | Backward 0.0058s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0762 | Loss 0.0882 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0763 | Loss 0.0875 | Best MRR 0.3054 | Forward 0.0237s | Backward 0.0048s
# # sampled nodes: 9944
# # sampled edges: 15000
# # nodes: 9944, # edges: 15000
# Done edge sampling
# Epoch 0764 | Loss 0.0882 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0050s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0765 | Loss 0.0890 | Best MRR 0.3054 | Forward 0.0249s | Backward 0.0051s
# # sampled nodes: 10055
# # sampled edges: 15000
# # nodes: 10055, # edges: 15000
# Done edge sampling
# Epoch 0766 | Loss 0.0884 | Best MRR 0.3054 | Forward 0.0240s | Backward 0.0054s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0767 | Loss 0.0867 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0051s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0768 | Loss 0.0887 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0065s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0769 | Loss 0.0883 | Best MRR 0.3054 | Forward 0.0258s | Backward 0.0050s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 0770 | Loss 0.0876 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0117s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0771 | Loss 0.0869 | Best MRR 0.3054 | Forward 0.0240s | Backward 0.0051s
# # sampled nodes: 9934
# # sampled edges: 15000
# # nodes: 9934, # edges: 15000
# Done edge sampling
# Epoch 0772 | Loss 0.0883 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0048s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0773 | Loss 0.0891 | Best MRR 0.3054 | Forward 0.0267s | Backward 0.0111s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0774 | Loss 0.0887 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0059s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 0775 | Loss 0.0886 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0079s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0776 | Loss 0.0894 | Best MRR 0.3054 | Forward 0.0237s | Backward 0.0049s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 0777 | Loss 0.0889 | Best MRR 0.3054 | Forward 0.0255s | Backward 0.0053s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0778 | Loss 0.0868 | Best MRR 0.3054 | Forward 0.0246s | Backward 0.0050s
# # sampled nodes: 9990
# # sampled edges: 15000
# # nodes: 9990, # edges: 15000
# Done edge sampling
# Epoch 0779 | Loss 0.0883 | Best MRR 0.3054 | Forward 0.0248s | Backward 0.0051s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0780 | Loss 0.0881 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.1066s
# # sampled nodes: 9957
# # sampled edges: 15000
# # nodes: 9957, # edges: 15000
# Done edge sampling
# Epoch 0781 | Loss 0.0894 | Best MRR 0.3054 | Forward 0.0245s | Backward 0.0049s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0782 | Loss 0.0872 | Best MRR 0.3054 | Forward 0.0242s | Backward 0.0076s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0783 | Loss 0.0872 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0049s
# # sampled nodes: 9942
# # sampled edges: 15000
# # nodes: 9942, # edges: 15000
# Done edge sampling
# Epoch 0784 | Loss 0.0875 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0054s
# # sampled nodes: 9944
# # sampled edges: 15000
# # nodes: 9944, # edges: 15000
# Done edge sampling
# Epoch 0785 | Loss 0.0877 | Best MRR 0.3054 | Forward 0.0239s | Backward 0.0048s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0786 | Loss 0.0878 | Best MRR 0.3054 | Forward 0.0241s | Backward 0.0048s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0787 | Loss 0.0881 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0049s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0788 | Loss 0.0868 | Best MRR 0.3054 | Forward 0.0248s | Backward 0.0050s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0789 | Loss 0.0877 | Best MRR 0.3054 | Forward 0.0264s | Backward 0.0162s
# # sampled nodes: 10010
# # sampled edges: 15000
# # nodes: 10010, # edges: 15000
# Done edge sampling
# Epoch 0790 | Loss 0.0871 | Best MRR 0.3054 | Forward 0.0255s | Backward 0.0171s
# # sampled nodes: 9955
# # sampled edges: 15000
# # nodes: 9955, # edges: 15000
# Done edge sampling
# Epoch 0791 | Loss 0.0882 | Best MRR 0.3054 | Forward 0.0244s | Backward 0.0048s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0792 | Loss 0.0885 | Best MRR 0.3054 | Forward 0.0237s | Backward 0.0051s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0793 | Loss 0.0876 | Best MRR 0.3054 | Forward 0.0270s | Backward 0.0050s
# # sampled nodes: 10005
# # sampled edges: 15000
# # nodes: 10005, # edges: 15000
# Done edge sampling
# Epoch 0794 | Loss 0.0895 | Best MRR 0.3054 | Forward 0.0238s | Backward 0.0052s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0795 | Loss 0.0866 | Best MRR 0.3054 | Forward 0.0236s | Backward 0.0051s
# # sampled nodes: 9982
# # sampled edges: 15000
# # nodes: 9982, # edges: 15000
# Done edge sampling
# Epoch 0796 | Loss 0.0887 | Best MRR 0.3054 | Forward 0.0237s | Backward 0.0048s
# # sampled nodes: 10012
# # sampled edges: 15000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-77c00df247e7> in <module>()
#      62             train_data, parameter_graph_batch_size, parameter_graph_split_size,
#      63             num_rels, adj_list, degrees, parameter_negative_sample,
# ---> 64             parameter_edge_sampler)
#      65     print("Done edge sampling")
#      66     # set node/edge feature
#
# /content/drive/My Drive/utils.py in generate_sampled_graph_and_labels(triplets, sample_size, split_size, num_rels, adj_list, degrees, negative_rate, sampler)
#     114     print("# sampled edges: {}".format(len(src) * 2))
#     115     g, rel, norm = build_graph_from_triplets(len(uniq_v), num_rels,
# --> 116                                              (src, rel, dst))
#     117     return g, uniq_v, rel, norm, samples, labels
#     118
#
# /content/drive/My Drive/utils.py in build_graph_from_triplets(num_nodes, num_rels, triplets)
#     135     src, dst = np.concatenate((src, dst)), np.concatenate((dst, src))
#     136     rel = np.concatenate((rel, rel + num_rels))
# --> 137     edges = sorted(zip(dst, src, rel))
#     138     dst, src, rel = np.array(edges).transpose()
#     139     g.add_edges(src, dst)
#
# KeyboardInterrupt:

# %%
#train_data = irgcn_train_data
# check cuda
use_cuda = parameter_gpu >= 0 and torch.cuda.is_available()
if use_cuda:
    torch.cuda.set_device(parameter_gpu)

# create model
model = IRGCN(num_nodes,
                    parameter_n_hidden,
                    num_rels,
                    num_bases=parameter_n_bases,
                    num_hidden_layers=parameter_n_layers,
                    dropout=parameter_dropout,
                    use_cuda=use_cuda,
                    reg_param=parameter_regularization)

# validation and testing triplets
train_data = np.array(train_data)
valid_data = torch.LongTensor(valid_data)
test_data = torch.LongTensor(test_data)

# build test graph
test_graph, test_rel, test_norm = utils.build_test_graph(
    num_nodes, num_rels, train_data)
test_deg = test_graph.in_degrees(
            range(test_graph.number_of_nodes())).float().view(-1,1)
test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
test_rel = torch.from_numpy(test_rel)
test_norm = node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))

if use_cuda:
    model.cuda()

# build adj list and calculate degrees for sampling
adj_list, degrees = utils.get_adj_and_degrees(num_nodes, train_data)

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=parameter_lr)

model_state_file = 'model_state_irgcn_2.pth'
forward_time = []
backward_time = []

# training loop
print("start training...")

epoch = 0
best_mrr = 0
while True:
    model.train()
    epoch += 1

    # perform edge neighborhood sampling to generate training graph and data
    g, node_id, edge_type, node_norm, data, labels = \
        utils.generate_sampled_graph_and_labels(
            train_data, parameter_graph_batch_size, parameter_graph_split_size,
            num_rels, adj_list, degrees, parameter_negative_sample,
            parameter_edge_sampler)
    print("Done edge sampling")
    #labels =(labels-0.5)*2
    # set node/edge feature
    node_id = torch.from_numpy(node_id).view(-1, 1).long()
    edge_type = torch.from_numpy(edge_type)
    edge_norm = node_norm_to_edge_norm(g, torch.from_numpy(node_norm).view(-1, 1))
    data, labels = torch.from_numpy(data), torch.from_numpy(labels)
    deg = g.in_degrees(range(g.number_of_nodes())).float().view(-1, 1)
    if use_cuda:
        node_id, deg = node_id.cuda(), deg.cuda()
        edge_type, edge_norm = edge_type.cuda(), edge_norm.cuda()
        data, labels = data.cuda(), labels.cuda()
        g = g.to(parameter_gpu)
        data, labels = data.cuda(), labels.cuda()

    t0 = time.time()


    model(g, node_id, edge_type, edge_norm, data, labels)

    loss = model.get_loss(g, data, labels)
    t1 = time.time()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), parameter_grad_norm) # clip gradients
    optimizer.step()
    t2 = time.time()

    forward_time.append(t1 - t0)
    backward_time.append(t2 - t1)
    print("Epoch {:04d} | Loss {:.4f} | Best MRR {:.4f} | Forward {:.4f}s | Backward {:.4f}s".
          format(epoch, loss.item(), best_mrr, forward_time[-1], backward_time[-1]))

    optimizer.zero_grad()

    # validation
    if epoch % parameter_evaluate_every == 0:
        # perform validation on CPU because full graph is too large
        if use_cuda:
            model.cpu()
        model.eval()
        print("start eval")
        mrr = utils.calc_mrr(model.embedding(test_graph, test_node_id, test_rel, test_norm), model.w_relation.cpu(), torch.LongTensor(train_data).cpu(),
                              valid_data, test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size,
                              eval_p=parameter_eval_protocol)
        #save best model
        if best_mrr < mrr:
            best_mrr = mrr
            torch.save({'state_dict': model.state_dict(), 'epoch': epoch}, model_state_file)
        
        if epoch >= parameter_n_epochs:
            break
        
        if use_cuda:
            model.cuda()

print("training done")
print("Mean forward time: {:4f}s".format(np.mean(forward_time)))
print("Mean Backward time: {:4f}s".format(np.mean(backward_time)))

print("\nstart testing:")
# use best model checkpoint
checkpoint = torch.load(model_state_file)
if use_cuda:
    model.cpu() # test on CPU
model.eval()
model.load_state_dict(checkpoint['state_dict'])
print("Using best epoch: {}".format(checkpoint['epoch']))
utils.calc_mrr(model.embedding(test_graph, test_node_id, test_rel, test_norm), model.w_relation, torch.LongTensor(train_data), valid_data,
                test_data, hits=[1, 3, 10], eval_bz=parameter_eval_batch_size, eval_p=parameter_eval_protocol)
# Out:
# Test graph:
# # nodes: 11616, # edges: 65506
# start training...
# # sampled nodes: 10042
# # sampled edges: 15000
# # nodes: 10042, # edges: 15000
# Done edge sampling
# /content/drive/My Drive/utils.py:122: RuntimeWarning: divide by zero encountered in true_divide
#   norm = 1.0 / in_deg
# Streaming output truncated to the last 5000 lines.
# Done edge sampling
# Epoch 0608 | Loss 0.0434 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0850s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0609 | Loss 0.0419 | Best MRR 0.3615 | Forward 0.0334s | Backward 0.0858s
# # sampled nodes: 9947
# # sampled edges: 15000
# # nodes: 9947, # edges: 15000
# Done edge sampling
# Epoch 0610 | Loss 0.0441 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0841s
# # sampled nodes: 10029
# # sampled edges: 15000
# # nodes: 10029, # edges: 15000
# Done edge sampling
# Epoch 0611 | Loss 0.0438 | Best MRR 0.3615 | Forward 0.0353s | Backward 0.0850s
# # sampled nodes: 10034
# # sampled edges: 15000
# # nodes: 10034, # edges: 15000
# Done edge sampling
# Epoch 0612 | Loss 0.0418 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0874s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0613 | Loss 0.0424 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0857s
# # sampled nodes: 10073
# # sampled edges: 15000
# # nodes: 10073, # edges: 15000
# Done edge sampling
# Epoch 0614 | Loss 0.0421 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0852s
# # sampled nodes: 9975
# # sampled edges: 15000
# # nodes: 9975, # edges: 15000
# Done edge sampling
# Epoch 0615 | Loss 0.0428 | Best MRR 0.3615 | Forward 0.0348s | Backward 0.0852s
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# Epoch 0616 | Loss 0.0428 | Best MRR 0.3615 | Forward 0.0343s | Backward 0.0861s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0617 | Loss 0.0425 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0848s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0618 | Loss 0.0430 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0846s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0619 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0850s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0620 | Loss 0.0424 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0848s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0621 | Loss 0.0439 | Best MRR 0.3615 | Forward 0.0335s | Backward 0.0858s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0622 | Loss 0.0419 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0846s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0623 | Loss 0.0426 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0846s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0624 | Loss 0.0431 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0853s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0625 | Loss 0.0438 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0851s
# # sampled nodes: 9955
# # sampled edges: 15000
# # nodes: 9955, # edges: 15000
# Done edge sampling
# Epoch 0626 | Loss 0.0430 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0856s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0627 | Loss 0.0421 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0858s
# # sampled nodes: 9956
# # sampled edges: 15000
# # nodes: 9956, # edges: 15000
# Done edge sampling
# Epoch 0628 | Loss 0.0425 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0847s
# # sampled nodes: 9973
# # sampled edges: 15000
# # nodes: 9973, # edges: 15000
# Done edge sampling
# Epoch 0629 | Loss 0.0425 | Best MRR 0.3615 | Forward 0.0347s | Backward 0.0888s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0630 | Loss 0.0416 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0855s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0631 | Loss 0.0417 | Best MRR 0.3615 | Forward 0.0333s | Backward 0.0855s
# # sampled nodes: 9947
# # sampled edges: 15000
# # nodes: 9947, # edges: 15000
# Done edge sampling
# Epoch 0632 | Loss 0.0412 | Best MRR 0.3615 | Forward 0.0347s | Backward 0.0867s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0633 | Loss 0.0420 | Best MRR 0.3615 | Forward 0.0342s | Backward 0.0854s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 0634 | Loss 0.0406 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0860s
# # sampled nodes: 10039
# # sampled edges: 15000
# # nodes: 10039, # edges: 15000
# Done edge sampling
# Epoch 0635 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0340s | Backward 0.0853s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0636 | Loss 0.0406 | Best MRR 0.3615 | Forward 0.0348s | Backward 0.0853s
# # sampled nodes: 9925
# # sampled edges: 15000
# # nodes: 9925, # edges: 15000
# Done edge sampling
# Epoch 0637 | Loss 0.0423 | Best MRR 0.3615 | Forward 0.0344s | Backward 0.0856s
# # sampled nodes: 10030
# # sampled edges: 15000
# # nodes: 10030, # edges: 15000
# Done edge sampling
# Epoch 0638 | Loss 0.0412 | Best MRR 0.3615 | Forward 0.0372s | Backward 0.0859s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0639 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0855s
# # sampled nodes: 10047
# # sampled edges: 15000
# # nodes: 10047, # edges: 15000
# Done edge sampling
# Epoch 0640 | Loss 0.0419 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0842s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0641 | Loss 0.0416 | Best MRR 0.3615 | Forward 0.0386s | Backward 0.1120s
# # sampled nodes: 9961
# # sampled edges: 15000
# # nodes: 9961, # edges: 15000
# Done edge sampling
# Epoch 0642 | Loss 0.0418 | Best MRR 0.3615 | Forward 0.0373s | Backward 0.0985s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0643 | Loss 0.0429 | Best MRR 0.3615 | Forward 0.0354s | Backward 0.0920s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0644 | Loss 0.0414 | Best MRR 0.3615 | Forward 0.0374s | Backward 0.0969s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0645 | Loss 0.0424 | Best MRR 0.3615 | Forward 0.0350s | Backward 0.0942s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0646 | Loss 0.0410 | Best MRR 0.3615 | Forward 0.0397s | Backward 0.0978s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0647 | Loss 0.0419 | Best MRR 0.3615 | Forward 0.0367s | Backward 0.0866s
# # sampled nodes: 9958
# # sampled edges: 15000
# # nodes: 9958, # edges: 15000
# Done edge sampling
# Epoch 0648 | Loss 0.0419 | Best MRR 0.3615 | Forward 0.0335s | Backward 0.0844s
# # sampled nodes: 10004
# # sampled edges: 15000
# # nodes: 10004, # edges: 15000
# Done edge sampling
# Epoch 0649 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0856s
# # sampled nodes: 9936
# # sampled edges: 15000
# # nodes: 9936, # edges: 15000
# Done edge sampling
# Epoch 0650 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0872s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0651 | Loss 0.0403 | Best MRR 0.3615 | Forward 0.0344s | Backward 0.0857s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 0652 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0848s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0653 | Loss 0.0421 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0851s
# # sampled nodes: 9984
# # sampled edges: 15000
# # nodes: 9984, # edges: 15000
# Done edge sampling
# Epoch 0654 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0346s | Backward 0.0898s
# # sampled nodes: 9940
# # sampled edges: 15000
# # nodes: 9940, # edges: 15000
# Done edge sampling
# Epoch 0655 | Loss 0.0435 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0842s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0656 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0344s | Backward 0.0853s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0657 | Loss 0.0417 | Best MRR 0.3615 | Forward 0.0334s | Backward 0.0847s
# # sampled nodes: 10049
# # sampled edges: 15000
# # nodes: 10049, # edges: 15000
# Done edge sampling
# Epoch 0658 | Loss 0.0430 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0849s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0659 | Loss 0.0405 | Best MRR 0.3615 | Forward 0.0349s | Backward 0.0849s
# # sampled nodes: 10042
# # sampled edges: 15000
# # nodes: 10042, # edges: 15000
# Done edge sampling
# Epoch 0660 | Loss 0.0409 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0849s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0661 | Loss 0.0403 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0852s
# # sampled nodes: 9947
# # sampled edges: 15000
# # nodes: 9947, # edges: 15000
# Done edge sampling
# Epoch 0662 | Loss 0.0416 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0852s
# # sampled nodes: 10010
# # sampled edges: 15000
# # nodes: 10010, # edges: 15000
# Done edge sampling
# Epoch 0663 | Loss 0.0409 | Best MRR 0.3615 | Forward 0.0341s | Backward 0.0851s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0664 | Loss 0.0412 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0856s
# # sampled nodes: 9976
# # sampled edges: 15000
# # nodes: 9976, # edges: 15000
# Done edge sampling
# Epoch 0665 | Loss 0.0424 | Best MRR 0.3615 | Forward 0.0347s | Backward 0.0862s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 0666 | Loss 0.0406 | Best MRR 0.3615 | Forward 0.0332s | Backward 0.0855s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 0667 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0342s | Backward 0.0849s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0668 | Loss 0.0403 | Best MRR 0.3615 | Forward 0.0363s | Backward 0.0856s
# # sampled nodes: 9939
# # sampled edges: 15000
# # nodes: 9939, # edges: 15000
# Done edge sampling
# Epoch 0669 | Loss 0.0422 | Best MRR 0.3615 | Forward 0.0344s | Backward 0.0858s
# # sampled nodes: 9961
# # sampled edges: 15000
# # nodes: 9961, # edges: 15000
# Done edge sampling
# Epoch 0670 | Loss 0.0416 | Best MRR 0.3615 | Forward 0.0358s | Backward 0.1355s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0671 | Loss 0.0407 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0872s
# # sampled nodes: 9942
# # sampled edges: 15000
# # nodes: 9942, # edges: 15000
# Done edge sampling
# Epoch 0672 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0856s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 0673 | Loss 0.0410 | Best MRR 0.3615 | Forward 0.0340s | Backward 0.0862s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0674 | Loss 0.0406 | Best MRR 0.3615 | Forward 0.0333s | Backward 0.0873s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0675 | Loss 0.0413 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0873s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0676 | Loss 0.0409 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0846s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0677 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0853s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0678 | Loss 0.0396 | Best MRR 0.3615 | Forward 0.0345s | Backward 0.0911s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 0679 | Loss 0.0400 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0861s
# # sampled nodes: 9950
# # sampled edges: 15000
# # nodes: 9950, # edges: 15000
# Done edge sampling
# Epoch 0680 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0845s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0681 | Loss 0.0405 | Best MRR 0.3615 | Forward 0.0341s | Backward 0.0841s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0682 | Loss 0.0404 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0859s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0683 | Loss 0.0404 | Best MRR 0.3615 | Forward 0.0335s | Backward 0.0855s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 0684 | Loss 0.0412 | Best MRR 0.3615 | Forward 0.0344s | Backward 0.0863s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0685 | Loss 0.0414 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0865s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0686 | Loss 0.0405 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0862s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0687 | Loss 0.0409 | Best MRR 0.3615 | Forward 0.0339s | Backward 0.0849s
# # sampled nodes: 10045
# # sampled edges: 15000
# # nodes: 10045, # edges: 15000
# Done edge sampling
# Epoch 0688 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0334s | Backward 0.0876s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0689 | Loss 0.0417 | Best MRR 0.3615 | Forward 0.0336s | Backward 0.0854s
# # sampled nodes: 9976
# # sampled edges: 15000
# # nodes: 9976, # edges: 15000
# Done edge sampling
# Epoch 0690 | Loss 0.0410 | Best MRR 0.3615 | Forward 0.0335s | Backward 0.0853s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0691 | Loss 0.0404 | Best MRR 0.3615 | Forward 0.0338s | Backward 0.0848s
# # sampled nodes: 10062
# # sampled edges: 15000
# # nodes: 10062, # edges: 15000
# Done edge sampling
# Epoch 0692 | Loss 0.0407 | Best MRR 0.3615 | Forward 0.0335s | Backward 0.0851s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0693 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0348s | Backward 0.1321s
# # sampled nodes: 9951
# # sampled edges: 15000
# # nodes: 9951, # edges: 15000
# Done edge sampling
# Epoch 0694 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0359s | Backward 0.0851s
# # sampled nodes: 10010
# # sampled edges: 15000
# # nodes: 10010, # edges: 15000
# Done edge sampling
# Epoch 0695 | Loss 0.0421 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0855s
# # sampled nodes: 9975
# # sampled edges: 15000
# # nodes: 9975, # edges: 15000
# Done edge sampling
# Epoch 0696 | Loss 0.0402 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0875s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0697 | Loss 0.0406 | Best MRR 0.3615 | Forward 0.0345s | Backward 0.0866s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 0698 | Loss 0.0415 | Best MRR 0.3615 | Forward 0.0369s | Backward 0.0870s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0699 | Loss 0.0412 | Best MRR 0.3615 | Forward 0.0343s | Backward 0.0881s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0700 | Loss 0.0411 | Best MRR 0.3615 | Forward 0.0337s | Backward 0.0856s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.366639
# Hits (filtered) @ 1: 0.140850
# Hits (filtered) @ 3: 0.449966
# Hits (filtered) @ 10: 0.917066
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0701 | Loss 0.0412 | Best MRR 0.3666 | Forward 0.0473s | Backward 0.1204s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0702 | Loss 0.0407 | Best MRR 0.3666 | Forward 0.0427s | Backward 0.1072s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0703 | Loss 0.0409 | Best MRR 0.3666 | Forward 0.0392s | Backward 0.0979s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0704 | Loss 0.0412 | Best MRR 0.3666 | Forward 0.0382s | Backward 0.0917s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0705 | Loss 0.0404 | Best MRR 0.3666 | Forward 0.0366s | Backward 0.0924s
# # sampled nodes: 10010
# # sampled edges: 15000
# # nodes: 10010, # edges: 15000
# Done edge sampling
# Epoch 0706 | Loss 0.0405 | Best MRR 0.3666 | Forward 0.0343s | Backward 0.0894s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0707 | Loss 0.0407 | Best MRR 0.3666 | Forward 0.0349s | Backward 0.0868s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0708 | Loss 0.0401 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0843s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0709 | Loss 0.0408 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0851s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 0710 | Loss 0.0403 | Best MRR 0.3666 | Forward 0.0345s | Backward 0.0860s
# # sampled nodes: 10014
# # sampled edges: 15000
# # nodes: 10014, # edges: 15000
# Done edge sampling
# Epoch 0711 | Loss 0.0397 | Best MRR 0.3666 | Forward 0.0354s | Backward 0.0864s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0712 | Loss 0.0405 | Best MRR 0.3666 | Forward 0.0365s | Backward 0.0853s
# # sampled nodes: 9994
# # sampled edges: 15000
# # nodes: 9994, # edges: 15000
# Done edge sampling
# Epoch 0713 | Loss 0.0388 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0851s
# # sampled nodes: 9975
# # sampled edges: 15000
# # nodes: 9975, # edges: 15000
# Done edge sampling
# Epoch 0714 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0849s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0715 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0335s | Backward 0.0859s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0716 | Loss 0.0408 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0889s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 0717 | Loss 0.0390 | Best MRR 0.3666 | Forward 0.0345s | Backward 0.0863s
# # sampled nodes: 9941
# # sampled edges: 15000
# # nodes: 9941, # edges: 15000
# Done edge sampling
# Epoch 0718 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0335s | Backward 0.0854s
# # sampled nodes: 10055
# # sampled edges: 15000
# # nodes: 10055, # edges: 15000
# Done edge sampling
# Epoch 0719 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.1356s
# # sampled nodes: 10018
# # sampled edges: 15000
# # nodes: 10018, # edges: 15000
# Done edge sampling
# Epoch 0720 | Loss 0.0405 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0854s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 0721 | Loss 0.0411 | Best MRR 0.3666 | Forward 0.0341s | Backward 0.0855s
# # sampled nodes: 10018
# # sampled edges: 15000
# # nodes: 10018, # edges: 15000
# Done edge sampling
# Epoch 0722 | Loss 0.0398 | Best MRR 0.3666 | Forward 0.0358s | Backward 0.0849s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0723 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0855s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0724 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0350s | Backward 0.0861s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0725 | Loss 0.0393 | Best MRR 0.3666 | Forward 0.0361s | Backward 0.0859s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0726 | Loss 0.0404 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0862s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 0727 | Loss 0.0416 | Best MRR 0.3666 | Forward 0.0377s | Backward 0.1346s
# # sampled nodes: 9958
# # sampled edges: 15000
# # nodes: 9958, # edges: 15000
# Done edge sampling
# Epoch 0728 | Loss 0.0391 | Best MRR 0.3666 | Forward 0.0375s | Backward 0.0949s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0729 | Loss 0.0407 | Best MRR 0.3666 | Forward 0.0419s | Backward 0.0915s
# # sampled nodes: 9958
# # sampled edges: 15000
# # nodes: 9958, # edges: 15000
# Done edge sampling
# Epoch 0730 | Loss 0.0410 | Best MRR 0.3666 | Forward 0.0347s | Backward 0.0935s
# # sampled nodes: 10048
# # sampled edges: 15000
# # nodes: 10048, # edges: 15000
# Done edge sampling
# Epoch 0731 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0347s | Backward 0.0898s
# # sampled nodes: 9969
# # sampled edges: 15000
# # nodes: 9969, # edges: 15000
# Done edge sampling
# Epoch 0732 | Loss 0.0411 | Best MRR 0.3666 | Forward 0.0368s | Backward 0.0980s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0733 | Loss 0.0391 | Best MRR 0.3666 | Forward 0.0364s | Backward 0.0850s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0734 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0341s | Backward 0.0852s
# # sampled nodes: 10054
# # sampled edges: 15000
# # nodes: 10054, # edges: 15000
# Done edge sampling
# Epoch 0735 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0865s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0736 | Loss 0.0389 | Best MRR 0.3666 | Forward 0.0342s | Backward 0.0847s
# # sampled nodes: 9973
# # sampled edges: 15000
# # nodes: 9973, # edges: 15000
# Done edge sampling
# Epoch 0737 | Loss 0.0399 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0869s
# # sampled nodes: 10039
# # sampled edges: 15000
# # nodes: 10039, # edges: 15000
# Done edge sampling
# Epoch 0738 | Loss 0.0393 | Best MRR 0.3666 | Forward 0.0341s | Backward 0.0852s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0739 | Loss 0.0397 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0864s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0740 | Loss 0.0401 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0862s
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# Epoch 0741 | Loss 0.0399 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0857s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0742 | Loss 0.0398 | Best MRR 0.3666 | Forward 0.0343s | Backward 0.0859s
# # sampled nodes: 9963
# # sampled edges: 15000
# # nodes: 9963, # edges: 15000
# Done edge sampling
# Epoch 0743 | Loss 0.0408 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0857s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0744 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0862s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0745 | Loss 0.0411 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0863s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 0746 | Loss 0.0403 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0898s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0747 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0855s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0748 | Loss 0.0405 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0856s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0749 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0860s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0750 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0860s
# # sampled nodes: 10038
# # sampled edges: 15000
# # nodes: 10038, # edges: 15000
# Done edge sampling
# Epoch 0751 | Loss 0.0398 | Best MRR 0.3666 | Forward 0.0345s | Backward 0.0859s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 0752 | Loss 0.0376 | Best MRR 0.3666 | Forward 0.0345s | Backward 0.0862s
# # sampled nodes: 10017
# # sampled edges: 15000
# # nodes: 10017, # edges: 15000
# Done edge sampling
# Epoch 0753 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0858s
# # sampled nodes: 9972
# # sampled edges: 15000
# # nodes: 9972, # edges: 15000
# Done edge sampling
# Epoch 0754 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0867s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0755 | Loss 0.0397 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0862s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0756 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0335s | Backward 0.0865s
# # sampled nodes: 9990
# # sampled edges: 15000
# # nodes: 9990, # edges: 15000
# Done edge sampling
# Epoch 0757 | Loss 0.0397 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0867s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 0758 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0865s
# # sampled nodes: 10040
# # sampled edges: 15000
# # nodes: 10040, # edges: 15000
# Done edge sampling
# Epoch 0759 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0867s
# # sampled nodes: 10020
# # sampled edges: 15000
# # nodes: 10020, # edges: 15000
# Done edge sampling
# Epoch 0760 | Loss 0.0396 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0875s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 0761 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0334s | Backward 0.0859s
# # sampled nodes: 10012
# # sampled edges: 15000
# # nodes: 10012, # edges: 15000
# Done edge sampling
# Epoch 0762 | Loss 0.0388 | Best MRR 0.3666 | Forward 0.0342s | Backward 0.0864s
# # sampled nodes: 10025
# # sampled edges: 15000
# # nodes: 10025, # edges: 15000
# Done edge sampling
# Epoch 0763 | Loss 0.0398 | Best MRR 0.3666 | Forward 0.0341s | Backward 0.0855s
# # sampled nodes: 9958
# # sampled edges: 15000
# # nodes: 9958, # edges: 15000
# Done edge sampling
# Epoch 0764 | Loss 0.0391 | Best MRR 0.3666 | Forward 0.0342s | Backward 0.0861s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0765 | Loss 0.0398 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0864s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0766 | Loss 0.0402 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0874s
# # sampled nodes: 9994
# # sampled edges: 15000
# # nodes: 9994, # edges: 15000
# Done edge sampling
# Epoch 0767 | Loss 0.0389 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0872s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0768 | Loss 0.0400 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0881s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 0769 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0857s
# # sampled nodes: 9950
# # sampled edges: 15000
# # nodes: 9950, # edges: 15000
# Done edge sampling
# Epoch 0770 | Loss 0.0393 | Best MRR 0.3666 | Forward 0.0367s | Backward 0.0859s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0771 | Loss 0.0407 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0864s
# # sampled nodes: 10029
# # sampled edges: 15000
# # nodes: 10029, # edges: 15000
# Done edge sampling
# Epoch 0772 | Loss 0.0394 | Best MRR 0.3666 | Forward 0.0343s | Backward 0.0869s
# # sampled nodes: 10002
# # sampled edges: 15000
# # nodes: 10002, # edges: 15000
# Done edge sampling
# Epoch 0773 | Loss 0.0407 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0848s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0774 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0335s | Backward 0.0855s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0775 | Loss 0.0374 | Best MRR 0.3666 | Forward 0.0349s | Backward 0.0861s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 0776 | Loss 0.0390 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0862s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0777 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0867s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0778 | Loss 0.0389 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0870s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 0779 | Loss 0.0401 | Best MRR 0.3666 | Forward 0.0342s | Backward 0.0858s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 0780 | Loss 0.0393 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0854s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0781 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0341s | Backward 0.0863s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 0782 | Loss 0.0403 | Best MRR 0.3666 | Forward 0.0335s | Backward 0.0870s
# # sampled nodes: 9993
# # sampled edges: 15000
# # nodes: 9993, # edges: 15000
# Done edge sampling
# Epoch 0783 | Loss 0.0400 | Best MRR 0.3666 | Forward 0.0348s | Backward 0.0858s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0784 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0867s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 0785 | Loss 0.0388 | Best MRR 0.3666 | Forward 0.0343s | Backward 0.0874s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 0786 | Loss 0.0392 | Best MRR 0.3666 | Forward 0.0342s | Backward 0.0868s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0787 | Loss 0.0382 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0869s
# # sampled nodes: 9988
# # sampled edges: 15000
# # nodes: 9988, # edges: 15000
# Done edge sampling
# Epoch 0788 | Loss 0.0387 | Best MRR 0.3666 | Forward 0.0334s | Backward 0.0888s
# # sampled nodes: 10064
# # sampled edges: 15000
# # nodes: 10064, # edges: 15000
# Done edge sampling
# Epoch 0789 | Loss 0.0383 | Best MRR 0.3666 | Forward 0.0341s | Backward 0.0871s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0790 | Loss 0.0389 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0864s
# # sampled nodes: 9987
# # sampled edges: 15000
# # nodes: 9987, # edges: 15000
# Done edge sampling
# Epoch 0791 | Loss 0.0388 | Best MRR 0.3666 | Forward 0.0342s | Backward 0.0867s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 0792 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0863s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 0793 | Loss 0.0395 | Best MRR 0.3666 | Forward 0.0338s | Backward 0.0866s
# # sampled nodes: 10018
# # sampled edges: 15000
# # nodes: 10018, # edges: 15000
# Done edge sampling
# Epoch 0794 | Loss 0.0384 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0865s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0795 | Loss 0.0383 | Best MRR 0.3666 | Forward 0.0339s | Backward 0.0862s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0796 | Loss 0.0390 | Best MRR 0.3666 | Forward 0.0336s | Backward 0.0867s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 0797 | Loss 0.0381 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0867s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0798 | Loss 0.0393 | Best MRR 0.3666 | Forward 0.0340s | Backward 0.0857s
# # sampled nodes: 9907
# # sampled edges: 15000
# # nodes: 9907, # edges: 15000
# Done edge sampling
# Epoch 0799 | Loss 0.0382 | Best MRR 0.3666 | Forward 0.0359s | Backward 0.0848s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 0800 | Loss 0.0376 | Best MRR 0.3666 | Forward 0.0337s | Backward 0.0853s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.374198
# Hits (filtered) @ 1: 0.146676
# Hits (filtered) @ 3: 0.461275
# Hits (filtered) @ 10: 0.919465
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0801 | Loss 0.0383 | Best MRR 0.3742 | Forward 0.0478s | Backward 0.1206s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0802 | Loss 0.0381 | Best MRR 0.3742 | Forward 0.0439s | Backward 0.1091s
# # sampled nodes: 9985
# # sampled edges: 15000
# # nodes: 9985, # edges: 15000
# Done edge sampling
# Epoch 0803 | Loss 0.0384 | Best MRR 0.3742 | Forward 0.0393s | Backward 0.1007s
# # sampled nodes: 9952
# # sampled edges: 15000
# # nodes: 9952, # edges: 15000
# Done edge sampling
# Epoch 0804 | Loss 0.0394 | Best MRR 0.3742 | Forward 0.0360s | Backward 0.0914s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0805 | Loss 0.0389 | Best MRR 0.3742 | Forward 0.0337s | Backward 0.0857s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0806 | Loss 0.0392 | Best MRR 0.3742 | Forward 0.0339s | Backward 0.0849s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0807 | Loss 0.0395 | Best MRR 0.3742 | Forward 0.0335s | Backward 0.0868s
# # sampled nodes: 9956
# # sampled edges: 15000
# # nodes: 9956, # edges: 15000
# Done edge sampling
# Epoch 0808 | Loss 0.0379 | Best MRR 0.3742 | Forward 0.0331s | Backward 0.0848s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 0809 | Loss 0.0381 | Best MRR 0.3742 | Forward 0.0332s | Backward 0.0849s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0810 | Loss 0.0372 | Best MRR 0.3742 | Forward 0.0339s | Backward 0.0855s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0811 | Loss 0.0392 | Best MRR 0.3742 | Forward 0.0345s | Backward 0.0854s
# # sampled nodes: 9954
# # sampled edges: 15000
# # nodes: 9954, # edges: 15000
# Done edge sampling
# Epoch 0812 | Loss 0.0386 | Best MRR 0.3742 | Forward 0.0337s | Backward 0.0862s
# # sampled nodes: 9957
# # sampled edges: 15000
# # nodes: 9957, # edges: 15000
# Done edge sampling
# Epoch 0813 | Loss 0.0389 | Best MRR 0.3742 | Forward 0.0377s | Backward 0.0856s
# # sampled nodes: 10010
# # sampled edges: 15000
# # nodes: 10010, # edges: 15000
# Done edge sampling
# Epoch 0814 | Loss 0.0392 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0889s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0815 | Loss 0.0393 | Best MRR 0.3742 | Forward 0.0334s | Backward 0.0865s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 0816 | Loss 0.0391 | Best MRR 0.3742 | Forward 0.0335s | Backward 0.0848s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0817 | Loss 0.0385 | Best MRR 0.3742 | Forward 0.0347s | Backward 0.0858s
# # sampled nodes: 9963
# # sampled edges: 15000
# # nodes: 9963, # edges: 15000
# Done edge sampling
# Epoch 0818 | Loss 0.0393 | Best MRR 0.3742 | Forward 0.0334s | Backward 0.0871s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 0819 | Loss 0.0388 | Best MRR 0.3742 | Forward 0.0337s | Backward 0.0895s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0820 | Loss 0.0385 | Best MRR 0.3742 | Forward 0.0338s | Backward 0.0850s
# # sampled nodes: 10003
# # sampled edges: 15000
# # nodes: 10003, # edges: 15000
# Done edge sampling
# Epoch 0821 | Loss 0.0392 | Best MRR 0.3742 | Forward 0.0340s | Backward 0.0858s
# # sampled nodes: 9974
# # sampled edges: 15000
# # nodes: 9974, # edges: 15000
# Done edge sampling
# Epoch 0822 | Loss 0.0369 | Best MRR 0.3742 | Forward 0.0338s | Backward 0.0869s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0823 | Loss 0.0392 | Best MRR 0.3742 | Forward 0.0341s | Backward 0.0887s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0824 | Loss 0.0411 | Best MRR 0.3742 | Forward 0.0334s | Backward 0.0852s
# # sampled nodes: 9938
# # sampled edges: 15000
# # nodes: 9938, # edges: 15000
# Done edge sampling
# Epoch 0825 | Loss 0.0388 | Best MRR 0.3742 | Forward 0.0339s | Backward 0.0869s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0826 | Loss 0.0397 | Best MRR 0.3742 | Forward 0.0338s | Backward 0.0861s
# # sampled nodes: 9973
# # sampled edges: 15000
# # nodes: 9973, # edges: 15000
# Done edge sampling
# Epoch 0827 | Loss 0.0390 | Best MRR 0.3742 | Forward 0.0341s | Backward 0.0887s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 0828 | Loss 0.0402 | Best MRR 0.3742 | Forward 0.0348s | Backward 0.0862s
# # sampled nodes: 10041
# # sampled edges: 15000
# # nodes: 10041, # edges: 15000
# Done edge sampling
# Epoch 0829 | Loss 0.0396 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0848s
# # sampled nodes: 10015
# # sampled edges: 15000
# # nodes: 10015, # edges: 15000
# Done edge sampling
# Epoch 0830 | Loss 0.0399 | Best MRR 0.3742 | Forward 0.0342s | Backward 0.0865s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 0831 | Loss 0.0386 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0884s
# # sampled nodes: 9970
# # sampled edges: 15000
# # nodes: 9970, # edges: 15000
# Done edge sampling
# Epoch 0832 | Loss 0.0379 | Best MRR 0.3742 | Forward 0.0337s | Backward 0.0860s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 0833 | Loss 0.0390 | Best MRR 0.3742 | Forward 0.0334s | Backward 0.0854s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0834 | Loss 0.0388 | Best MRR 0.3742 | Forward 0.0364s | Backward 0.0848s
# # sampled nodes: 9937
# # sampled edges: 15000
# # nodes: 9937, # edges: 15000
# Done edge sampling
# Epoch 0835 | Loss 0.0388 | Best MRR 0.3742 | Forward 0.0337s | Backward 0.0856s
# # sampled nodes: 10030
# # sampled edges: 15000
# # nodes: 10030, # edges: 15000
# Done edge sampling
# Epoch 0836 | Loss 0.0395 | Best MRR 0.3742 | Forward 0.0344s | Backward 0.0865s
# # sampled nodes: 9990
# # sampled edges: 15000
# # nodes: 9990, # edges: 15000
# Done edge sampling
# Epoch 0837 | Loss 0.0381 | Best MRR 0.3742 | Forward 0.0339s | Backward 0.0859s
# # sampled nodes: 10024
# # sampled edges: 15000
# # nodes: 10024, # edges: 15000
# Done edge sampling
# Epoch 0838 | Loss 0.0385 | Best MRR 0.3742 | Forward 0.0342s | Backward 0.0869s
# # sampled nodes: 10037
# # sampled edges: 15000
# # nodes: 10037, # edges: 15000
# Done edge sampling
# Epoch 0839 | Loss 0.0385 | Best MRR 0.3742 | Forward 0.0339s | Backward 0.0873s
# # sampled nodes: 10044
# # sampled edges: 15000
# # nodes: 10044, # edges: 15000
# Done edge sampling
# Epoch 0840 | Loss 0.0384 | Best MRR 0.3742 | Forward 0.0338s | Backward 0.0865s
# # sampled nodes: 9954
# # sampled edges: 15000
# # nodes: 9954, # edges: 15000
# Done edge sampling
# Epoch 0841 | Loss 0.0379 | Best MRR 0.3742 | Forward 0.0341s | Backward 0.0851s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 0842 | Loss 0.0387 | Best MRR 0.3742 | Forward 0.0412s | Backward 0.0914s
# # sampled nodes: 9996
# # sampled edges: 15000
# # nodes: 9996, # edges: 15000
# Done edge sampling
# Epoch 0843 | Loss 0.0380 | Best MRR 0.3742 | Forward 0.0366s | Backward 0.0954s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 0844 | Loss 0.0387 | Best MRR 0.3742 | Forward 0.0407s | Backward 0.0918s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0845 | Loss 0.0390 | Best MRR 0.3742 | Forward 0.0366s | Backward 0.0932s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 0846 | Loss 0.0388 | Best MRR 0.3742 | Forward 0.0385s | Backward 0.0955s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0847 | Loss 0.0377 | Best MRR 0.3742 | Forward 0.0343s | Backward 0.0969s
# # sampled nodes: 10016
# # sampled edges: 15000
# # nodes: 10016, # edges: 15000
# Done edge sampling
# Epoch 0848 | Loss 0.0378 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0856s
# # sampled nodes: 9971
# # sampled edges: 15000
# # nodes: 9971, # edges: 15000
# Done edge sampling
# Epoch 0849 | Loss 0.0380 | Best MRR 0.3742 | Forward 0.0348s | Backward 0.0855s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0850 | Loss 0.0387 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0850s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 0851 | Loss 0.0370 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0849s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 0852 | Loss 0.0382 | Best MRR 0.3742 | Forward 0.0343s | Backward 0.0855s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 0853 | Loss 0.0388 | Best MRR 0.3742 | Forward 0.0348s | Backward 0.0853s
# # sampled nodes: 9979
# # sampled edges: 15000
# # nodes: 9979, # edges: 15000
# Done edge sampling
# Epoch 0854 | Loss 0.0362 | Best MRR 0.3742 | Forward 0.0337s | Backward 0.0856s
# # sampled nodes: 10020
# # sampled edges: 15000
# # nodes: 10020, # edges: 15000
# Done edge sampling
# Epoch 0855 | Loss 0.0377 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0868s
# # sampled nodes: 9992
# # sampled edges: 15000
# # nodes: 9992, # edges: 15000
# Done edge sampling
# Epoch 0856 | Loss 0.0368 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0861s
# # sampled nodes: 9999
# # sampled edges: 15000
# # nodes: 9999, # edges: 15000
# Done edge sampling
# Epoch 0857 | Loss 0.0385 | Best MRR 0.3742 | Forward 0.0358s | Backward 0.0859s
# # sampled nodes: 10045
# # sampled edges: 15000
# # nodes: 10045, # edges: 15000
# Done edge sampling
# Epoch 0858 | Loss 0.0398 | Best MRR 0.3742 | Forward 0.0346s | Backward 0.0853s
# # sampled nodes: 10064
# # sampled edges: 15000
# # nodes: 10064, # edges: 15000
# Done edge sampling
# Epoch 0859 | Loss 0.0381 | Best MRR 0.3742 | Forward 0.0335s | Backward 0.0861s
# # sampled nodes: 9926
# # sampled edges: 15000
# # nodes: 9926, # edges: 15000
# Done edge sampling
# Epoch 0860 | Loss 0.0379 | Best MRR 0.3742 | Forward 0.0335s | Backward 0.0857s
# # sampled nodes: 10035
# # sampled edges: 15000
# # nodes: 10035, # edges: 15000
# Done edge sampling
# Epoch 0861 | Loss 0.0386 | Best MRR 0.3742 | Forward 0.0369s | Backward 0.0851s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 0862 | Loss 0.0384 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0859s
# # sampled nodes: 10013
# # sampled edges: 15000
# # nodes: 10013, # edges: 15000
# Done edge sampling
# Epoch 0863 | Loss 0.0376 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0852s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 0864 | Loss 0.0378 | Best MRR 0.3742 | Forward 0.0335s | Backward 0.0900s
# # sampled nodes: 9952
# # sampled edges: 15000
# # nodes: 9952, # edges: 15000
# Done edge sampling
# Epoch 0865 | Loss 0.0372 | Best MRR 0.3742 | Forward 0.0333s | Backward 0.0852s
# # sampled nodes: 10029
# # sampled edges: 15000
# # nodes: 10029, # edges: 15000
# Done edge sampling
# Epoch 0866 | Loss 0.0384 | Best MRR 0.3742 | Forward 0.0336s | Backward 0.0852s
# # sampled nodes: 10028
# # sampled edges: 15000
# # nodes: 10028, # edges: 15000
# Done edge sampling
# Epoch 0867 | Loss 0.0371 | Best MRR 0.3742 | Forward 0.0341s | Backward 0.0850s
# # sampled nodes: 10029
# # sampled edges: 15000
# # nodes: 10029, # edges: 15000
# Done edge sampling
# Epoch 0868 | Loss 0.0380 | Best MRR 0.3742 | Forward 0.0333s | Backward 0.0843s
# # sampled nodes: 9977
# # sampled edges: 15000
# # nodes: 9977, # edges: 15000
# Done edge sampling
# Epoch 0869 | Loss 0.0362 | Best MRR 0.3742 | Forward 0.0334s | Backward 0.0862s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# ...
# Epoch 1467 | Loss 0.0341 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0846s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 1468 | Loss 0.0328 | Best MRR 0.3840 | Forward 0.0347s | Backward 0.0859s
# # sampled nodes: 10022
# # sampled edges: 15000
# # nodes: 10022, # edges: 15000
# Done edge sampling
# Epoch 1469 | Loss 0.0329 | Best MRR 0.3840 | Forward 0.0340s | Backward 0.0855s
# # sampled nodes: 10054
# # sampled edges: 15000
# # nodes: 10054, # edges: 15000
# Done edge sampling
# Epoch 1470 | Loss 0.0339 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0851s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 1471 | Loss 0.0348 | Best MRR 0.3840 | Forward 0.0341s | Backward 0.0849s
# # sampled nodes: 10012
# # sampled edges: 15000
# # nodes: 10012, # edges: 15000
# Done edge sampling
# Epoch 1472 | Loss 0.0321 | Best MRR 0.3840 | Forward 0.0365s | Backward 0.0852s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 1473 | Loss 0.0329 | Best MRR 0.3840 | Forward 0.0341s | Backward 0.0852s
# # sampled nodes: 10012
# # sampled edges: 15000
# # nodes: 10012, # edges: 15000
# Done edge sampling
# Epoch 1474 | Loss 0.0340 | Best MRR 0.3840 | Forward 0.0341s | Backward 0.0855s
# # sampled nodes: 9962
# # sampled edges: 15000
# # nodes: 9962, # edges: 15000
# Done edge sampling
# Epoch 1475 | Loss 0.0332 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0853s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 1476 | Loss 0.0323 | Best MRR 0.3840 | Forward 0.0341s | Backward 0.0851s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 1477 | Loss 0.0327 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0853s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 1478 | Loss 0.0329 | Best MRR 0.3840 | Forward 0.0342s | Backward 0.0874s
# # sampled nodes: 9990
# # sampled edges: 15000
# # nodes: 9990, # edges: 15000
# Done edge sampling
# Epoch 1479 | Loss 0.0327 | Best MRR 0.3840 | Forward 0.0359s | Backward 0.0852s
# # sampled nodes: 9957
# # sampled edges: 15000
# # nodes: 9957, # edges: 15000
# Done edge sampling
# Epoch 1480 | Loss 0.0330 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0868s
# # sampled nodes: 9967
# # sampled edges: 15000
# # nodes: 9967, # edges: 15000
# Done edge sampling
# Epoch 1481 | Loss 0.0344 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0867s
# # sampled nodes: 10012
# # sampled edges: 15000
# # nodes: 10012, # edges: 15000
# Done edge sampling
# Epoch 1482 | Loss 0.0331 | Best MRR 0.3840 | Forward 0.0347s | Backward 0.0855s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 1483 | Loss 0.0335 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0863s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 1484 | Loss 0.0334 | Best MRR 0.3840 | Forward 0.0341s | Backward 0.0864s
# # sampled nodes: 9950
# # sampled edges: 15000
# # nodes: 9950, # edges: 15000
# Done edge sampling
# Epoch 1485 | Loss 0.0330 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0901s
# # sampled nodes: 9997
# # sampled edges: 15000
# # nodes: 9997, # edges: 15000
# Done edge sampling
# Epoch 1486 | Loss 0.0320 | Best MRR 0.3840 | Forward 0.0349s | Backward 0.0880s
# # sampled nodes: 10005
# # sampled edges: 15000
# # nodes: 10005, # edges: 15000
# Done edge sampling
# Epoch 1487 | Loss 0.0336 | Best MRR 0.3840 | Forward 0.0334s | Backward 0.0848s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 1488 | Loss 0.0321 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0859s
# # sampled nodes: 10030
# # sampled edges: 15000
# # nodes: 10030, # edges: 15000
# Done edge sampling
# Epoch 1489 | Loss 0.0323 | Best MRR 0.3840 | Forward 0.0343s | Backward 0.0857s
# # sampled nodes: 9975
# # sampled edges: 15000
# # nodes: 9975, # edges: 15000
# Done edge sampling
# Epoch 1490 | Loss 0.0344 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0853s
# # sampled nodes: 10008
# # sampled edges: 15000
# # nodes: 10008, # edges: 15000
# Done edge sampling
# Epoch 1491 | Loss 0.0338 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0853s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 1492 | Loss 0.0328 | Best MRR 0.3840 | Forward 0.0361s | Backward 0.0856s
# # sampled nodes: 9970
# # sampled edges: 15000
# # nodes: 9970, # edges: 15000
# Done edge sampling
# Epoch 1493 | Loss 0.0329 | Best MRR 0.3840 | Forward 0.0340s | Backward 0.0856s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 1494 | Loss 0.0327 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0870s
# # sampled nodes: 9991
# # sampled edges: 15000
# # nodes: 9991, # edges: 15000
# Done edge sampling
# Epoch 1495 | Loss 0.0329 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0861s
# # sampled nodes: 10041
# # sampled edges: 15000
# # nodes: 10041, # edges: 15000
# Done edge sampling
# Epoch 1496 | Loss 0.0330 | Best MRR 0.3840 | Forward 0.0354s | Backward 0.0852s
# # sampled nodes: 10053
# # sampled edges: 15000
# # nodes: 10053, # edges: 15000
# Done edge sampling
# Epoch 1497 | Loss 0.0334 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0857s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 1498 | Loss 0.0330 | Best MRR 0.3840 | Forward 0.0366s | Backward 0.0853s
# # sampled nodes: 10054
# # sampled edges: 15000
# # nodes: 10054, # edges: 15000
# Done edge sampling
# Epoch 1499 | Loss 0.0330 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0861s
# # sampled nodes: 10027
# # sampled edges: 15000
# # nodes: 10027, # edges: 15000
# Done edge sampling
# Epoch 1500 | Loss 0.0332 | Best MRR 0.3840 | Forward 0.0344s | Backward 0.0863s
# start eval
# Perturbing subject...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# Perturbing object...
# test triplet 0 / 1459
# test triplet 100 / 1459
# test triplet 200 / 1459
# test triplet 300 / 1459
# test triplet 400 / 1459
# test triplet 500 / 1459
# test triplet 600 / 1459
# test triplet 700 / 1459
# test triplet 800 / 1459
# test triplet 900 / 1459
# test triplet 1000 / 1459
# test triplet 1100 / 1459
# test triplet 1200 / 1459
# test triplet 1300 / 1459
# test triplet 1400 / 1459
# MRR (filtered): 0.375086
# Hits (filtered) @ 1: 0.139136
# Hits (filtered) @ 3: 0.466073
# Hits (filtered) @ 10: 0.936943
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 1501 | Loss 0.0333 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0875s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 1502 | Loss 0.0323 | Best MRR 0.3840 | Forward 0.0348s | Backward 0.0853s
# # sampled nodes: 9959
# # sampled edges: 15000
# # nodes: 9959, # edges: 15000
# Done edge sampling
# Epoch 1503 | Loss 0.0329 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0864s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 1504 | Loss 0.0324 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0872s
# # sampled nodes: 10019
# # sampled edges: 15000
# # nodes: 10019, # edges: 15000
# Done edge sampling
# Epoch 1505 | Loss 0.0336 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0903s
# # sampled nodes: 10006
# # sampled edges: 15000
# # nodes: 10006, # edges: 15000
# Done edge sampling
# Epoch 1506 | Loss 0.0328 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0873s
# # sampled nodes: 9973
# # sampled edges: 15000
# # nodes: 9973, # edges: 15000
# Done edge sampling
# Epoch 1507 | Loss 0.0335 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0852s
# # sampled nodes: 10016
# # sampled edges: 15000
# # nodes: 10016, # edges: 15000
# Done edge sampling
# Epoch 1508 | Loss 0.0321 | Best MRR 0.3840 | Forward 0.0341s | Backward 0.0852s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 1509 | Loss 0.0325 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0852s
# # sampled nodes: 9983
# # sampled edges: 15000
# # nodes: 9983, # edges: 15000
# Done edge sampling
# Epoch 1510 | Loss 0.0331 | Best MRR 0.3840 | Forward 0.0346s | Backward 0.0861s
# # sampled nodes: 9978
# # sampled edges: 15000
# # nodes: 9978, # edges: 15000
# Done edge sampling
# Epoch 1511 | Loss 0.0325 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0855s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 1512 | Loss 0.0328 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0851s
# # sampled nodes: 9941
# # sampled edges: 15000
# # nodes: 9941, # edges: 15000
# Done edge sampling
# Epoch 1513 | Loss 0.0321 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0854s
# # sampled nodes: 10021
# # sampled edges: 15000
# # nodes: 10021, # edges: 15000
# Done edge sampling
# Epoch 1514 | Loss 0.0331 | Best MRR 0.3840 | Forward 0.0342s | Backward 0.0903s
# # sampled nodes: 9998
# # sampled edges: 15000
# # nodes: 9998, # edges: 15000
# Done edge sampling
# Epoch 1515 | Loss 0.0324 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0847s
# # sampled nodes: 10040
# # sampled edges: 15000
# # nodes: 10040, # edges: 15000
# Done edge sampling
# Epoch 1516 | Loss 0.0327 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0855s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 1517 | Loss 0.0332 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0852s
# # sampled nodes: 9953
# # sampled edges: 15000
# # nodes: 9953, # edges: 15000
# Done edge sampling
# Epoch 1518 | Loss 0.0327 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0845s
# # sampled nodes: 10009
# # sampled edges: 15000
# # nodes: 10009, # edges: 15000
# Done edge sampling
# Epoch 1519 | Loss 0.0326 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0858s
# # sampled nodes: 10000
# # sampled edges: 15000
# # nodes: 10000, # edges: 15000
# Done edge sampling
# Epoch 1520 | Loss 0.0318 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0865s
# # sampled nodes: 9965
# # sampled edges: 15000
# # nodes: 9965, # edges: 15000
# Done edge sampling
# Epoch 1521 | Loss 0.0331 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0862s
# # sampled nodes: 10011
# # sampled edges: 15000
# # nodes: 10011, # edges: 15000
# Done edge sampling
# Epoch 1522 | Loss 0.0339 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0854s
# # sampled nodes: 10050
# # sampled edges: 15000
# # nodes: 10050, # edges: 15000
# Done edge sampling
# Epoch 1523 | Loss 0.0323 | Best MRR 0.3840 | Forward 0.0346s | Backward 0.0853s
# # sampled nodes: 9942
# # sampled edges: 15000
# # nodes: 9942, # edges: 15000
# Done edge sampling
# Epoch 1524 | Loss 0.0325 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0852s
# # sampled nodes: 10023
# # sampled edges: 15000
# # nodes: 10023, # edges: 15000
# Done edge sampling
# Epoch 1525 | Loss 0.0334 | Best MRR 0.3840 | Forward 0.0340s | Backward 0.0857s
# # sampled nodes: 9989
# # sampled edges: 15000
# # nodes: 9989, # edges: 15000
# Done edge sampling
# Epoch 1526 | Loss 0.0326 | Best MRR 0.3840 | Forward 0.0337s | Backward 0.0866s
# # sampled nodes: 10026
# # sampled edges: 15000
# # nodes: 10026, # edges: 15000
# Done edge sampling
# Epoch 1527 | Loss 0.0328 | Best MRR 0.3840 | Forward 0.0340s | Backward 0.0866s
# # sampled nodes: 9966
# # sampled edges: 15000
# # nodes: 9966, # edges: 15000
# Done edge sampling
# Epoch 1528 | Loss 0.0328 | Best MRR 0.3840 | Forward 0.0345s | Backward 0.0855s
# # sampled nodes: 9980
# # sampled edges: 15000
# # nodes: 9980, # edges: 15000
# Done edge sampling
# Epoch 1529 | Loss 0.0325 | Best MRR 0.3840 | Forward 0.0337s | Backward 0.0863s
# # sampled nodes: 10001
# # sampled edges: 15000
# # nodes: 10001, # edges: 15000
# Done edge sampling
# Epoch 1530 | Loss 0.0322 | Best MRR 0.3840 | Forward 0.0340s | Backward 0.0854s
# # sampled nodes: 9948
# # sampled edges: 15000
# # nodes: 9948, # edges: 15000
# Done edge sampling
# Epoch 1531 | Loss 0.0326 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0859s
# # sampled nodes: 10007
# # sampled edges: 15000
# # nodes: 10007, # edges: 15000
# Done edge sampling
# Epoch 1532 | Loss 0.0326 | Best MRR 0.3840 | Forward 0.0344s | Backward 0.1334s
# # sampled nodes: 9995
# # sampled edges: 15000
# # nodes: 9995, # edges: 15000
# Done edge sampling
# Epoch 1533 | Loss 0.0335 | Best MRR 0.3840 | Forward 0.0335s | Backward 0.0854s
# # sampled nodes: 10046
# # sampled edges: 15000
# # nodes: 10046, # edges: 15000
# Done edge sampling
# Epoch 1534 | Loss 0.0319 | Best MRR 0.3840 | Forward 0.0336s | Backward 0.0854s
# # sampled nodes: 9960
# # sampled edges: 15000
# # nodes: 9960, # edges: 15000
# Done edge sampling
# Epoch 1535 | Loss 0.0327 | Best MRR 0.3840 | Forward 0.0347s | Backward 0.0852s
# # sampled nodes: 9937
# # sampled edges: 15000
# # nodes: 9937, # edges: 15000
# Done edge sampling
# Epoch 1536 | Loss 0.0331 | Best MRR 0.3840 | Forward 0.0344s | Backward 0.0858s
# # sampled nodes: 9968
# # sampled edges: 15000
# # nodes: 9968, # edges: 15000
# Done edge sampling
# Epoch 1537 | Loss 0.0323 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0856s
# # sampled nodes: 9951
# # sampled edges: 15000
# # nodes: 9951, # edges: 15000
# Done edge sampling
# Epoch 1538 | Loss 0.0333 | Best MRR 0.3840 | Forward 0.0337s | Backward 0.0860s
# # sampled nodes: 9892
# # sampled edges: 15000
# # nodes: 9892, # edges: 15000
# Done edge sampling
# Epoch 1539 | Loss 0.0322 | Best MRR 0.3840 | Forward 0.0339s | Backward 0.0869s
# # sampled nodes: 9981
# # sampled edges: 15000
# # nodes: 9981, # edges: 15000
# Done edge sampling
# Epoch 1540 | Loss 0.0322 | Best MRR 0.3840 | Forward 0.0340s | Backward 0.0860s
# # sampled nodes: 9986
# # sampled edges: 15000
# # nodes: 9986, # edges: 15000
# Done edge sampling
# Epoch 1541 | Loss 0.0335 | Best MRR 0.3840 | Forward 0.0338s | Backward 0.0863s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-a93a201d913e> in <module>()
#      55             train_data, parameter_graph_batch_size, parameter_graph_split_size,
#      56             num_rels, adj_list, degrees, parameter_negative_sample,
# ---> 57             parameter_edge_sampler)
#      58     print("Done edge sampling")
#      59     #labels =(labels-0.5)*2
#
# /content/drive/My Drive/utils.py in generate_sampled_graph_and_labels(triplets, sample_size, split_size, num_rels, adj_list, degrees, negative_rate, sampler)
#      84     # perform edge neighbor sampling
#      85     if sampler == "uniform":
# ---> 86         edges = sample_edge_uniform(adj_list, degrees, len(triplets), sample_size)
#      87     elif sampler == "neighbor":
#      88         edges = sample_edge_neighborhood(adj_list, degrees, len(triplets), sample_size)
#
# /content/drive/My Drive/utils.py in sample_edge_uniform(adj_list, degrees, n_triplets, sample_size)
#      73     """Sample edges uniformly from all the edges."""
#      74     all_edges = np.arange(n_triplets)
# ---> 75     return np.random.choice(all_edges, sample_size, replace=False)
#      76
#      77 def generate_sampled_graph_and_labels(triplets, sample_size, split_size,
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# <__array_function__ internals> in prod(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial, where)
#    2998     """
#    2999     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
# -> 3000                           keepdims=keepdims, initial=initial, where=where)
#    3001
#    3002
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:
